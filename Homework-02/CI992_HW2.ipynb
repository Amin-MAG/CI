# %% [markdown]
# # Your info
#
# Full name: M.Amin Ghasvari
#
# Student ID: 97521432

# %% [markdown]
# Notice: **You can add new cells for each part.**

# %% [markdown]
# # Q1.A. Kohonen

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
class Kohonen:
    # distance measurement mechanisms
    COSINE = 'cosine'
    EUCLIDEAN = 'euclidean'
    NONE = 'none'

    LEARNING_RATE_DECAY = 1
    UPDATE_RANGE_FACTOR = 0.25
    UPDATE_RANGE_DECAY = 1

    def __init__(self, width, height, dimension):
        self.x = width
        self.y = height
        self.node_dim = dimension

        # fitting main variables
        self.n_iter = 0  # number of the iterations
        self.batch_size = 0  # number of each batch
        self.input_arr = np.array([])  # input array, given in fit function
        self.dist_method = Kohonen.NONE  # the distance mechanism

        self.node_vectors = np.array([])  # nodes' vectors

        # learning rate
        self.learning_rate = 0

        self.update_range = 0  # the range and distance that would be updated
        self.neighbor_diff = np.array([])

        self.weights = np.array([])  # the neighbor weights
        self.x_delta = []
        self.y_delta = []

    def init_map(self):
        """
        generates random numbers for node vectors and normalize them with mean of the input array.
        :return:
        """
        random_array = np.random.rand(self.y, self.x, self.node_dim)
        normal_factor = (np.mean(self.input_arr) / np.mean(random_array))
        self.node_vectors = random_array * normal_factor

    def distance(self, vector_a, vector_b):
        """
        calculate the distance between vector_a and vector_b
        :param vector_a:
        :param vector_b:
        :return:
        """
        if self.dist_method == Kohonen.COSINE:
            # https://en.wikipedia.org/wiki/Cosine_similarity
            dist = 1. - np.dot(vector_a, vector_b) / (np.linalg.norm(vector_a) * np.linalg.norm(vector_b))
        elif self.dist_method == Kohonen.EUCLIDEAN:
            dist = np.linalg.norm(vector_a - vector_b)
        else:
            raise TypeError
        return dist

    def update_node_vectors(self, closest_nodes_idx):
        """
        updating the weights
        :param closest_nodes_idx:
        :return:
        """
        for idx in range(closest_nodes_idx.shape[0]):
            y = closest_nodes_idx[idx, 0]
            x = closest_nodes_idx[idx, 1]
            inp_idx = closest_nodes_idx[idx, 2]
            input_vector = self.input_arr[inp_idx]

            x_range = x + self.x_delta + self.update_range
            y_range = y + self.y_delta + self.update_range

            previous = self.node_vectors[y_range, x_range]

            update_vector = self.weights * self.learning_rate * (np.expand_dims(input_vector, axis=0) - previous)

            self.node_vectors[y_range, x_range, :] += update_vector

    def find_best_matching_node(self, data_vector):
        """
        this method is for finding best & closest vector.
        :param data_vector:
        :return: (x, y, distance) coordinates and distance
        """
        min_dist = None
        x = None
        y = None
        for y_idx in range(self.y):
            for x_idx in range(self.x):
                node_vector = self.node_vectors[y_idx + self.update_range, x_idx + self.update_range]
                dist = self.distance(data_vector, node_vector)
                if min_dist is None or min_dist > dist:
                    min_dist = dist
                    x = x_idx
                    y = y_idx

        return y, x, min_dist

    def calculate_neighbor_diff(self):
        """
        find diff for calculating sigma. diff is (x[i,j] - mean) ^ 2
        :return:
        """
        size = self.update_range * 2
        mean = size / 2.0

        diff = []
        y_delta = []
        x_delta = []
        for i in range(size):
            diff.append([])
            for j in range(size):
                diff[i].append([])
                for k in range(self.node_dim):
                    diff[i][j].append((j - mean) ** 2.0 + (i - mean) ** 2.0)
                y_delta.append(i - int(mean))
                x_delta.append(j - int(mean))

        self.neighbor_diff = np.array(diff)
        self.x_delta = np.array(x_delta, dtype=np.int32)
        self.y_delta = np.array(y_delta, dtype=np.int32)

    def calculate_neighbor_effect(self, iteration):
        """
        calculate the effect of update for the neighbors using Gaussian bell equation.
        :param iteration: the equation depends on the iteration index
        :return:
        """

        size = self.update_range * 2

        # standard deviation
        standard_deviation_factor = (size / 2) * Kohonen.UPDATE_RANGE_DECAY ** (iteration * 0.3 + 1)
        standard_deviation = standard_deviation_factor * (np.sum(self.neighbor_diff) ** (1 / 2)) / size ** 2

        # standard calculate the Gaussian bell plot
        e_factor = 1.0 / (math.sqrt(2 * math.pi) * standard_deviation)
        e_exponent_factor = (-1 / 2) * (1 / standard_deviation) ** 2
        weights = e_factor * math.e ** (e_exponent_factor * self.neighbor_diff)

        weights /= np.max(weights)
        weights = weights.reshape(size * size, 3)
        self.weights = weights

    def fit(self, input_arr, n_iter, batch_size=30, learning_rate=0.25, random_sampling=1.0, dist_method=EUCLIDEAN):
        """
        fit method is for training kohonen map.
        :param input_arr:
        :param n_iter:
        :param batch_size:
        :param learning_rate:
        :param random_sampling:
        :param dist_method:
        :return:
        """

        self.input_arr = input_arr
        self.n_iter = n_iter
        self.batch_size = batch_size
        self.dist_method = dist_method
        self.learning_rate = learning_rate
        self.update_range = int(min(self.x, self.y) * Kohonen.UPDATE_RANGE_FACTOR)

        self.init_map()

        # add some fake element to the vectors to ease the process of updating neighbors
        radius = self.update_range
        size = 2 * radius
        tmp_node_vectors = np.zeros((self.y + size, self.x + size, self.node_dim))
        tmp_node_vectors[radius: radius + self.y, radius: radius + self.x] = self.node_vectors.copy()
        self.node_vectors = tmp_node_vectors

        # sampling and batches
        n_samples = int(self.input_arr.shape[0] * random_sampling)
        data_idx_arr = np.arange(self.input_arr.shape[0])
        np.random.shuffle(data_idx_arr)
        batch_count = math.floor(n_samples / self.batch_size)

        self.calculate_neighbor_diff()

        # training
        for iter_idx in range(self.n_iter):

            # calculate update effect on the neighbors
            self.calculate_neighbor_effect(iter_idx)

            # Temporary variables
            total_dist = 0

            for batch in range(batch_count):
                closest_nodes_idx = np.zeros((self.batch_size, 3), dtype=np.int32)

                for item in range(self.batch_size):
                    input_idx = data_idx_arr[batch * self.batch_size + item]
                    input_vector = self.input_arr[input_idx]
                    y, x, dist = self.find_best_matching_node(input_vector)
                    closest_nodes_idx[item, 0] = y
                    closest_nodes_idx[item, 1] = x
                    closest_nodes_idx[item, 2] = input_idx
                    total_dist += dist

                self.update_node_vectors(closest_nodes_idx)

            print('Iteration {}/{} Average distance = {}'.format(iter_idx + 1, self.n_iter, total_dist / n_samples))

            self.learning_rate *= Kohonen.LEARNING_RATE_DECAY

        import matplotlib.pyplot as plt
        plt.imshow((self.node_vectors * 100).astype(int))
        plt.show()

        # Remove padding from the vector map
        self.node_vectors = self.node_vectors[self.update_range: self.update_range + self.y,
                            self.update_range: self.update_range + self.x]

        print("Training has been done !")

# %%
    NUMBER_OF_PIXELS = 1600

    # generating 1600 rgb colors
    pixels = np.random.randint(0, 255, NUMBER_OF_PIXELS * 3) / 100  # scale them into [0, 2.55]
    pixels = pixels.reshape(NUMBER_OF_PIXELS, 3)  # reshape them to rgb shape 1 * 3
    initial_pixels = pixels.reshape((40, 40, 3))
    plt.imshow((initial_pixels * 100).astype(int))
    plt.show()

# %%
    # set initial variables
    som = Kohonen(dimension=3, width=40, height=40)

    # fitting to the Kohonen map
    som.fit(pixels, random_sampling=0.4, n_iter=20, dist_method=Kohonen.EUCLIDEAN)

    result = (som.node_vectors * 100).astype(int)
    plt.imshow(result)
    plt.show()
# Out:
# Iteration 1/20 Average distance = 0.38334824777644155
# Iteration 2/20 Average distance = 0.3709910630604407
# Iteration 3/20 Average distance = 0.37214070725175397
# Iteration 4/20 Average distance = 0.36499568572276364
# Iteration 5/20 Average distance = 0.36388078804882884
# Iteration 6/20 Average distance = 0.3608497199939
# Iteration 7/20 Average distance = 0.3610701033587841
# Iteration 8/20 Average distance = 0.3630742375329059
# Iteration 9/20 Average distance = 0.36229316117653754
# Iteration 10/20 Average distance = 0.3577243148473997
# Iteration 11/20 Average distance = 0.3606179562297101
# Iteration 12/20 Average distance = 0.36017718393166664
# Iteration 13/20 Average distance = 0.3626820780312396
# Iteration 14/20 Average distance = 0.3573605107038034
# Iteration 15/20 Average distance = 0.3586435800315451
# Iteration 16/20 Average distance = 0.3637424151413178
# Iteration 17/20 Average distance = 0.36657324624640086
# Iteration 18/20 Average distance = 0.3738830025658697
# Iteration 19/20 Average distance = 0.37524215225569724
# Iteration 20/20 Average distance = 0.37230705671785735
# Training has been done !

# %%
    # set initial variables
    som = Kohonen(dimension=3, width=40, height=40)

    # fitting to the Kohonen map
    som.fit(pixels, random_sampling=0.4, n_iter=20, dist_method=Kohonen.COSINE)

    result = (som.node_vectors * 100).astype(int)
    plt.imshow(result)
    plt.show()
# Out:
# Iteration 1/20 Average distance = 0.007238321139882542
# Iteration 2/20 Average distance = 0.004742612030519847
# Iteration 3/20 Average distance = 0.004332082767549854
# Iteration 4/20 Average distance = 0.0042964906458975
# Iteration 5/20 Average distance = 0.0044240614041779645
# Iteration 6/20 Average distance = 0.004470276391047875
# Iteration 7/20 Average distance = 0.004441946735189814
# Iteration 8/20 Average distance = 0.004432417283674365
# Iteration 9/20 Average distance = 0.0043233787818662455
# Iteration 10/20 Average distance = 0.004371164270182239
# Iteration 11/20 Average distance = 0.004132998478457036
# Iteration 12/20 Average distance = 0.0043610098972258204
# Iteration 13/20 Average distance = 0.004717237178199174
# Iteration 14/20 Average distance = 0.004438560087007336
# Iteration 15/20 Average distance = 0.004027040664375189
# Iteration 16/20 Average distance = 0.004077027366648824
# Iteration 17/20 Average distance = 0.004055858053411967
# Iteration 18/20 Average distance = 0.004113153023937376
# Iteration 19/20 Average distance = 0.004140771900691231
# Iteration 20/20 Average distance = 0.0040714239274439205
# Training has been done !

# %% [markdown]
# # Q1.B. Kohonen

# %%
class Kohonen:
    # distance measurement mechanisms
    COSINE = 'cosine'
    EUCLIDEAN = 'euclidean'
    NONE = 'none'

    LEARNING_RATE_DECAY = 0.76
    UPDATE_RANGE_FACTOR = 0.25
    UPDATE_RANGE_DECAY = 1

    def __init__(self, width, height, dimension):
        self.x = width
        self.y = height
        self.node_dim = dimension

        # fitting main variables
        self.n_iter = 0  # number of the iterations
        self.batch_size = 0  # number of each batch
        self.input_arr = np.array([])  # input array, given in fit function
        self.dist_method = Kohonen.NONE  # the distance mechanism

        self.node_vectors = np.array([])  # nodes' vectors

        # learning rate
        self.learning_rate = 0

        self.update_range = 0  # the range and distance that would be updated
        self.neighbor_diff = np.array([])

        self.weights = np.array([])  # the neighbor weights
        self.x_delta = []
        self.y_delta = []

    def init_map(self):
        """
        generates random numbers for node vectors and normalize them with mean of the input array.
        :return:
        """
        random_array = np.random.rand(self.y, self.x, self.node_dim)
        normal_factor = (np.mean(self.input_arr) / np.mean(random_array))
        self.node_vectors = random_array * normal_factor

    def distance(self, vector_a, vector_b):
        """
        calculate the distance between vector_a and vector_b
        :param vector_a:
        :param vector_b:
        :return:
        """
        if self.dist_method == Kohonen.COSINE:
            # https://en.wikipedia.org/wiki/Cosine_similarity
            dist = 1. - np.dot(vector_a, vector_b) / (np.linalg.norm(vector_a) * np.linalg.norm(vector_b))
        elif self.dist_method == Kohonen.EUCLIDEAN:
            dist = np.linalg.norm(vector_a - vector_b)
        else:
            raise TypeError
        return dist

    def update_node_vectors(self, closest_nodes_idx):
        """
        updating the weights
        :param closest_nodes_idx:
        :return:
        """
        for idx in range(closest_nodes_idx.shape[0]):
            y = closest_nodes_idx[idx, 0]
            x = closest_nodes_idx[idx, 1]
            inp_idx = closest_nodes_idx[idx, 2]
            input_vector = self.input_arr[inp_idx]

            x_range = x + self.x_delta + self.update_range
            y_range = y + self.y_delta + self.update_range

            previous = self.node_vectors[y_range, x_range]

            update_vector = self.weights * self.learning_rate * (np.expand_dims(input_vector, axis=0) - previous)

            self.node_vectors[y_range, x_range, :] += update_vector

    def find_best_matching_node(self, data_vector):
        """
        this method is for finding best & closest vector.
        :param data_vector:
        :return: (x, y, distance) coordinates and distance
        """
        min_dist = None
        x = None
        y = None
        for y_idx in range(self.y):
            for x_idx in range(self.x):
                node_vector = self.node_vectors[y_idx + self.update_range, x_idx + self.update_range]
                dist = self.distance(data_vector, node_vector)
                if min_dist is None or min_dist > dist:
                    min_dist = dist
                    x = x_idx
                    y = y_idx

        return y, x, min_dist

    def calculate_neighbor_diff(self):
        """
        find diff for calculating sigma. diff is (x[i,j] - mean) ^ 2
        :return:
        """
        size = self.update_range * 2
        mean = size / 2.0

        diff = []
        y_delta = []
        x_delta = []
        for i in range(size):
            diff.append([])
            for j in range(size):
                diff[i].append([])
                for k in range(self.node_dim):
                    diff[i][j].append((j - mean) ** 2.0 + (i - mean) ** 2.0)
                y_delta.append(i - int(mean))
                x_delta.append(j - int(mean))

        self.neighbor_diff = np.array(diff)
        self.x_delta = np.array(x_delta, dtype=np.int32)
        self.y_delta = np.array(y_delta, dtype=np.int32)

    def calculate_neighbor_effect(self, iteration):
        """
        calculate the effect of update for the neighbors using Gaussian bell equation.
        :param iteration: the equation depends on the iteration index
        :return:
        """

        size = self.update_range * 2

        # standard deviation
        standard_deviation_factor = (size / 2) * Kohonen.UPDATE_RANGE_DECAY ** (iteration * 0.3 + 1)
        standard_deviation = standard_deviation_factor * (np.sum(self.neighbor_diff) ** (1 / 2)) / size ** 2

        # standard calculate the Gaussian bell plot
        e_factor = 1.0 / (math.sqrt(2 * math.pi) * standard_deviation)
        e_exponent_factor = (-1 / 2) * (1 / standard_deviation) ** 2
        weights = e_factor * math.e ** (e_exponent_factor * self.neighbor_diff)

        weights /= np.max(weights)
        weights = weights.reshape(size * size, 3)
        self.weights = weights

    def fit(self, input_arr, n_iter, batch_size=30, learning_rate=0.25, random_sampling=1.0, dist_method=EUCLIDEAN):
        """
        fit method is for training kohonen map.
        :param input_arr:
        :param n_iter:
        :param batch_size:
        :param learning_rate:
        :param random_sampling:
        :param dist_method:
        :return:
        """

        self.input_arr = input_arr
        self.n_iter = n_iter
        self.batch_size = batch_size
        self.dist_method = dist_method
        self.learning_rate = learning_rate
        self.update_range = int(min(self.x, self.y) * Kohonen.UPDATE_RANGE_FACTOR)

        self.init_map()

        # add some fake element to the vectors to ease the process of updating neighbors
        radius = self.update_range
        size = 2 * radius
        tmp_node_vectors = np.zeros((self.y + size, self.x + size, self.node_dim))
        tmp_node_vectors[radius: radius + self.y, radius: radius + self.x] = self.node_vectors.copy()
        self.node_vectors = tmp_node_vectors

        # sampling and batches
        n_samples = int(self.input_arr.shape[0] * random_sampling)
        data_idx_arr = np.arange(self.input_arr.shape[0])
        np.random.shuffle(data_idx_arr)
        batch_count = math.floor(n_samples / self.batch_size)

        self.calculate_neighbor_diff()

        # training
        for iter_idx in range(self.n_iter):

            # calculate update effect on the neighbors
            self.calculate_neighbor_effect(iter_idx)

            # Temporary variables
            total_dist = 0

            for batch in range(batch_count):
                closest_nodes_idx = np.zeros((self.batch_size, 3), dtype=np.int32)

                for item in range(self.batch_size):
                    input_idx = data_idx_arr[batch * self.batch_size + item]
                    input_vector = self.input_arr[input_idx]
                    y, x, dist = self.find_best_matching_node(input_vector)
                    closest_nodes_idx[item, 0] = y
                    closest_nodes_idx[item, 1] = x
                    closest_nodes_idx[item, 2] = input_idx
                    total_dist += dist

                self.update_node_vectors(closest_nodes_idx)

            print('Iteration {}/{} Average distance = {}'.format(iter_idx + 1, self.n_iter, total_dist / n_samples))

            self.learning_rate *= Kohonen.LEARNING_RATE_DECAY

        import matplotlib.pyplot as plt
        plt.imshow((self.node_vectors * 100).astype(int))
        plt.show()

        # Remove padding from the vector map
        self.node_vectors = self.node_vectors[self.update_range: self.update_range + self.y,
                            self.update_range: self.update_range + self.x]

        print("Training has been done !")

# %%
    # set initial variables
    som = Kohonen(dimension=3, width=40, height=40)

    # fitting to the Kohonen map
    som.fit(pixels, random_sampling=0.4, n_iter=20, dist_method=Kohonen.EUCLIDEAN)

    result = (som.node_vectors * 100).astype(int)
    plt.imshow(result)
    plt.show()
# Out:
# Iteration 1/20 Average distance = 0.3753410235174989
# Iteration 2/20 Average distance = 0.35566300998430406
# Iteration 3/20 Average distance = 0.35338499243279864
# Iteration 4/20 Average distance = 0.34986238077079446
# Iteration 5/20 Average distance = 0.3492245721395055
# Iteration 6/20 Average distance = 0.34978280813607865
# Iteration 7/20 Average distance = 0.35002333763473653
# Iteration 8/20 Average distance = 0.3482793600202758
# Iteration 9/20 Average distance = 0.3472298041109815
# Iteration 10/20 Average distance = 0.3467494852092568
# Iteration 11/20 Average distance = 0.346168180236483
# Iteration 12/20 Average distance = 0.3463193197779214
# Iteration 13/20 Average distance = 0.34649944095125274
# Iteration 14/20 Average distance = 0.34634156654500786
# Iteration 15/20 Average distance = 0.34615786289974426
# Iteration 16/20 Average distance = 0.34594516900831584
# Iteration 17/20 Average distance = 0.34578332208280044
# Iteration 18/20 Average distance = 0.34563892848105293
# Iteration 19/20 Average distance = 0.34550485477972853
# Iteration 20/20 Average distance = 0.34539851509357944
# Training has been done !

# %%
    # set initial variables
    som = Kohonen(dimension=3, width=40, height=40)

    # fitting to the Kohonen map
    som.fit(pixels, random_sampling=0.4, n_iter=20, dist_method=Kohonen.COSINE)

    result = (som.node_vectors * 100).astype(int)
    plt.imshow(result)
    plt.show()
# Out:
# Iteration 1/20 Average distance = 0.0057127054267787445
# Iteration 2/20 Average distance = 0.0040315489061288675
# Iteration 3/20 Average distance = 0.0040856740708151195
# Iteration 4/20 Average distance = 0.0038802444054714703
# Iteration 5/20 Average distance = 0.00380949437219153
# Iteration 6/20 Average distance = 0.0037437794086671505
# Iteration 7/20 Average distance = 0.003686136902499147
# Iteration 8/20 Average distance = 0.0036125972734509402
# Iteration 9/20 Average distance = 0.0035683819020541907
# Iteration 10/20 Average distance = 0.0034912843492991286
# Iteration 11/20 Average distance = 0.0034442345030474284
# Iteration 12/20 Average distance = 0.003402752955056601
# Iteration 13/20 Average distance = 0.0033920881863908382
# Iteration 14/20 Average distance = 0.003381113322358046
# Iteration 15/20 Average distance = 0.0033693507518708643
# Iteration 16/20 Average distance = 0.0033597105051707487
# Iteration 17/20 Average distance = 0.003351750098806053
# Iteration 18/20 Average distance = 0.0033469929594497324
# Iteration 19/20 Average distance = 0.0033452435316516185
# Iteration 20/20 Average distance = 0.0033428087713823092
# Training has been done !

# %%
class Kohonen:
    # distance measurement mechanisms
    COSINE = 'cosine'
    EUCLIDEAN = 'euclidean'
    NONE = 'none'

    LEARNING_RATE_DECAY = 0.78
    UPDATE_RANGE_FACTOR = 0.75
    UPDATE_RANGE_DECAY = 0.75

    def __init__(self, width, height, dimension):
        self.x = width
        self.y = height
        self.node_dim = dimension

        # fitting main variables
        self.n_iter = 0  # number of the iterations
        self.batch_size = 0  # number of each batch
        self.input_arr = np.array([])  # input array, given in fit function
        self.dist_method = Kohonen.NONE  # the distance mechanism

        self.node_vectors = np.array([])  # nodes' vectors

        # learning rate
        self.learning_rate = 0

        self.update_range = 0  # the range and distance that would be updated
        self.neighbor_diff = np.array([])

        self.weights = np.array([])  # the neighbor weights
        self.x_delta = []
        self.y_delta = []

    def init_map(self):
        """
        generates random numbers for node vectors and normalize them with mean of the input array.
        :return:
        """
        random_array = np.random.rand(self.y, self.x, self.node_dim)
        normal_factor = (np.mean(self.input_arr) / np.mean(random_array))
        self.node_vectors = random_array * normal_factor

    def distance(self, vector_a, vector_b):
        """
        calculate the distance between vector_a and vector_b
        :param vector_a:
        :param vector_b:
        :return:
        """
        if self.dist_method == Kohonen.COSINE:
            # https://en.wikipedia.org/wiki/Cosine_similarity
            dist = 1. - np.dot(vector_a, vector_b) / (np.linalg.norm(vector_a) * np.linalg.norm(vector_b))
        elif self.dist_method == Kohonen.EUCLIDEAN:
            dist = np.linalg.norm(vector_a - vector_b)
        else:
            raise TypeError
        return dist

    def update_node_vectors(self, closest_nodes_idx):
        """
        updating the weights
        :param closest_nodes_idx:
        :return:
        """
        for idx in range(closest_nodes_idx.shape[0]):
            y = closest_nodes_idx[idx, 0]
            x = closest_nodes_idx[idx, 1]
            inp_idx = closest_nodes_idx[idx, 2]
            input_vector = self.input_arr[inp_idx]

            x_range = x + self.x_delta + self.update_range
            y_range = y + self.y_delta + self.update_range

            previous = self.node_vectors[y_range, x_range]

            update_vector = self.weights * self.learning_rate * (np.expand_dims(input_vector, axis=0) - previous)

            self.node_vectors[y_range, x_range, :] += update_vector

    def find_best_matching_node(self, data_vector):
        """
        this method is for finding best & closest vector.
        :param data_vector:
        :return: (x, y, distance) coordinates and distance
        """
        min_dist = None
        x = None
        y = None
        for y_idx in range(self.y):
            for x_idx in range(self.x):
                node_vector = self.node_vectors[y_idx + self.update_range, x_idx + self.update_range]
                dist = self.distance(data_vector, node_vector)
                if min_dist is None or min_dist > dist:
                    min_dist = dist
                    x = x_idx
                    y = y_idx

        return y, x, min_dist

    def calculate_neighbor_diff(self):
        """
        find diff for calculating sigma. diff is (x[i,j] - mean) ^ 2
        :return:
        """
        size = self.update_range * 2
        mean = size / 2.0

        diff = []
        y_delta = []
        x_delta = []
        for i in range(size):
            diff.append([])
            for j in range(size):
                diff[i].append([])
                for k in range(self.node_dim):
                    diff[i][j].append((j - mean) ** 2.0 + (i - mean) ** 2.0)
                y_delta.append(i - int(mean))
                x_delta.append(j - int(mean))

        self.neighbor_diff = np.array(diff)
        self.x_delta = np.array(x_delta, dtype=np.int32)
        self.y_delta = np.array(y_delta, dtype=np.int32)

    def calculate_neighbor_effect(self, iteration):
        """
        calculate the effect of update for the neighbors using Gaussian bell equation.
        :param iteration: the equation depends on the iteration index
        :return:
        """

        size = self.update_range * 2

        # standard deviation
        standard_deviation_factor = (size / 2) * Kohonen.UPDATE_RANGE_DECAY ** (iteration * 0.3 + 1)
        standard_deviation = standard_deviation_factor * (np.sum(self.neighbor_diff) ** (1 / 2)) / size ** 2

        # standard calculate the Gaussian bell plot
        e_factor = 1.0 / (math.sqrt(2 * math.pi) * standard_deviation)
        e_exponent_factor = (-1 / 2) * (1 / standard_deviation) ** 2
        weights = e_factor * math.e ** (e_exponent_factor * self.neighbor_diff)

        weights /= np.max(weights)
        weights = weights.reshape(size * size, 3)
        self.weights = weights

    def fit(self, input_arr, n_iter, batch_size=30, learning_rate=0.25, random_sampling=1.0, dist_method=EUCLIDEAN):
        """
        fit method is for training kohonen map.
        :param input_arr:
        :param n_iter:
        :param batch_size:
        :param learning_rate:
        :param random_sampling:
        :param dist_method:
        :return:
        """

        self.input_arr = input_arr
        self.n_iter = n_iter
        self.batch_size = batch_size
        self.dist_method = dist_method
        self.learning_rate = learning_rate
        self.update_range = int(min(self.x, self.y) * Kohonen.UPDATE_RANGE_FACTOR)

        self.init_map()

        # add some fake element to the vectors to ease the process of updating neighbors
        radius = self.update_range
        size = 2 * radius
        tmp_node_vectors = np.zeros((self.y + size, self.x + size, self.node_dim))
        tmp_node_vectors[radius: radius + self.y, radius: radius + self.x] = self.node_vectors.copy()
        self.node_vectors = tmp_node_vectors

        # sampling and batches
        n_samples = int(self.input_arr.shape[0] * random_sampling)
        data_idx_arr = np.arange(self.input_arr.shape[0])
        np.random.shuffle(data_idx_arr)
        batch_count = math.floor(n_samples / self.batch_size)

        self.calculate_neighbor_diff()

        # training
        for iter_idx in range(self.n_iter):

            # calculate update effect on the neighbors
            self.calculate_neighbor_effect(iter_idx)

            # Temporary variables
            total_dist = 0

            for batch in range(batch_count):
                closest_nodes_idx = np.zeros((self.batch_size, 3), dtype=np.int32)

                for item in range(self.batch_size):
                    input_idx = data_idx_arr[batch * self.batch_size + item]
                    input_vector = self.input_arr[input_idx]
                    y, x, dist = self.find_best_matching_node(input_vector)
                    closest_nodes_idx[item, 0] = y
                    closest_nodes_idx[item, 1] = x
                    closest_nodes_idx[item, 2] = input_idx
                    total_dist += dist

                self.update_node_vectors(closest_nodes_idx)

            print('Iteration {}/{} Average distance = {}'.format(iter_idx + 1, self.n_iter, total_dist / n_samples))

            self.learning_rate *= Kohonen.LEARNING_RATE_DECAY

        import matplotlib.pyplot as plt
        plt.imshow((self.node_vectors * 100).astype(int))
        plt.show()

        # Remove padding from the vector map
        self.node_vectors = self.node_vectors[self.update_range: self.update_range + self.y,
                            self.update_range: self.update_range + self.x]

        print("Training has been done !")

# %%
    # set initial variables
    som = Kohonen(dimension=3, width=40, height=40)

    # fitting to the Kohonen map
    som.fit(pixels, random_sampling=0.4, n_iter=20, dist_method=Kohonen.EUCLIDEAN)

    result = (som.node_vectors * 100).astype(int)
    plt.imshow(result)
    plt.show()
# Out:
# Iteration 1/20 Average distance = 0.7001130733080974
# Iteration 2/20 Average distance = 0.6918917535952305
# Iteration 3/20 Average distance = 0.6646875704015665
# Iteration 4/20 Average distance = 0.6325332548963047
# Iteration 5/20 Average distance = 0.5988669564904234
# Iteration 6/20 Average distance = 0.5604165437966675
# Iteration 7/20 Average distance = 0.5246746586719649
# Iteration 8/20 Average distance = 0.4925666591047104
# Iteration 9/20 Average distance = 0.46459329506997904
# Iteration 10/20 Average distance = 0.4398099140634546
# Iteration 11/20 Average distance = 0.41804454876723474
# Iteration 12/20 Average distance = 0.3998870132681341
# Iteration 13/20 Average distance = 0.38483798429960353
# Iteration 14/20 Average distance = 0.37181740382616485
# Iteration 15/20 Average distance = 0.36093702678099426
# Iteration 16/20 Average distance = 0.35208035128990606
# Iteration 17/20 Average distance = 0.34490246542451886
# Iteration 18/20 Average distance = 0.3391236230716531
# Iteration 19/20 Average distance = 0.33460018015033477
# Iteration 20/20 Average distance = 0.3310626693716352
# Training has been done !

# %%
    # set initial variables
    som = Kohonen(dimension=3, width=40, height=40)

    # fitting to the Kohonen map
    som.fit(pixels, random_sampling=0.4, n_iter=20, dist_method=Kohonen.COSINE)

    result = (som.node_vectors * 100).astype(int)
    plt.imshow(result)
    plt.show()
# Out:
# Iteration 1/20 Average distance = 0.02643953097853039
# Iteration 2/20 Average distance = 0.022553913228291582
# Iteration 3/20 Average distance = 0.020525273753026377
# Iteration 4/20 Average distance = 0.018348686466439116
# Iteration 5/20 Average distance = 0.016245963054530927
# Iteration 6/20 Average distance = 0.014211122204282386
# Iteration 7/20 Average distance = 0.012336046541724734
# Iteration 8/20 Average distance = 0.010649801698899904
# Iteration 9/20 Average distance = 0.0091848466260281
# Iteration 10/20 Average distance = 0.00793838934744466
# Iteration 11/20 Average distance = 0.006899279456558362
# Iteration 12/20 Average distance = 0.006030005682125357
# Iteration 13/20 Average distance = 0.00532889076075795
# Iteration 14/20 Average distance = 0.004765287938737354
# Iteration 15/20 Average distance = 0.00431571270368873
# Iteration 16/20 Average distance = 0.003962916563399225
# Iteration 17/20 Average distance = 0.0036862142062644085
# Iteration 18/20 Average distance = 0.0034713038235936544
# Iteration 19/20 Average distance = 0.0033056820038511654
# Iteration 20/20 Average distance = 0.0031775865205149545
# Training has been done !

# %% [markdown]
# # Q2.A. MLP

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from keras.datasets import mnist
from keras.optimizers import Adam
from keras import Sequential
from keras.layers import Dense
from keras.callbacks import History
import matplotlib.pyplot as plt

# %%
RANGE = 5

# generate the data
x_train = (np.random.rand(4000) - 0.5) * 2
x_test = (np.random.rand(500) - 0.5) * 2
x_train, x_test = x_train.reshape(4000, 1), x_test.reshape(500, 1)
y_train, y_test = (np.sin(x_train * RANGE) + 1)/2 , (np.sin(x_test * RANGE) + 1)/2

model = Sequential([
    Dense(units=30, input_shape=(1,), activation="relu"),
    Dense(units=60, activation="sigmoid"),
    Dense(units=1, activation="sigmoid")
])
model.summary()

batch_size = 200
epochs = 3000
# model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.compile(loss='mean_squared_error', optimizer='SGD', metrics=['mean_squared_error', 'accuracy'])
# history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1, verbose=2)

history = History()
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1, verbose=2, callbacks=[history])
predictions = model.predict(x_test)
print(np.mean(np.square(predictions - y_test)))

#
# fig, (ax_acc, err_ax) = plt.subplots(1, 2)
#
# err_ax.plot(np.arange(epochs), history.history.get('loss'))
# ax_acc.plot(np.arange(epochs), history.history.get('accuracy'))
#
# fig.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# 18/18 - 0s - loss: 0.1246 - mean_squared_error: 0.1246 - accuracy: 0.0000e+00 - val_loss: 0.1255 - val_mean_squared_error: 0.1255 - val_accuracy: 0.0000e+00
# Epoch 502/3000
# 18/18 - 0s - loss: 0.1245 - mean_squared_error: 0.1245 - accuracy: 0.0000e+00 - val_loss: 0.1255 - val_mean_squared_error: 0.1255 - val_accuracy: 0.0000e+00
# Epoch 503/3000
# 18/18 - 0s - loss: 0.1245 - mean_squared_error: 0.1245 - accuracy: 0.0000e+00 - val_loss: 0.1254 - val_mean_squared_error: 0.1254 - val_accuracy: 0.0000e+00
# Epoch 504/3000
# 18/18 - 0s - loss: 0.1245 - mean_squared_error: 0.1245 - accuracy: 0.0000e+00 - val_loss: 0.1254 - val_mean_squared_error: 0.1254 - val_accuracy: 0.0000e+00
# Epoch 505/3000
# 18/18 - 0s - loss: 0.1245 - mean_squared_error: 0.1245 - accuracy: 0.0000e+00 - val_loss: 0.1254 - val_mean_squared_error: 0.1254 - val_accuracy: 0.0000e+00
# Epoch 506/3000
# 18/18 - 0s - loss: 0.1245 - mean_squared_error: 0.1245 - accuracy: 0.0000e+00 - val_loss: 0.1254 - val_mean_squared_error: 0.1254 - val_accuracy: 0.0000e+00
# Epoch 507/3000
# 18/18 - 0s - loss: 0.1244 - mean_squared_error: 0.1244 - accuracy: 0.0000e+00 - val_loss: 0.1253 - val_mean_squared_error: 0.1253 - val_accuracy: 0.0000e+00
# Epoch 508/3000
# 18/18 - 0s - loss: 0.1244 - mean_squared_error: 0.1244 - accuracy: 0.0000e+00 - val_loss: 0.1253 - val_mean_squared_error: 0.1253 - val_accuracy: 0.0000e+00
# Epoch 509/3000
# 18/18 - 0s - loss: 0.1244 - mean_squared_error: 0.1244 - accuracy: 0.0000e+00 - val_loss: 0.1253 - val_mean_squared_error: 0.1253 - val_accuracy: 0.0000e+00
# Epoch 510/3000
# 18/18 - 0s - loss: 0.1244 - mean_squared_error: 0.1244 - accuracy: 0.0000e+00 - val_loss: 0.1252 - val_mean_squared_error: 0.1252 - val_accuracy: 0.0000e+00
# Epoch 511/3000
# 18/18 - 0s - loss: 0.1244 - mean_squared_error: 0.1244 - accuracy: 0.0000e+00 - val_loss: 0.1252 - val_mean_squared_error: 0.1252 - val_accuracy: 0.0000e+00
# Epoch 512/3000
# 18/18 - 0s - loss: 0.1243 - mean_squared_error: 0.1243 - accuracy: 0.0000e+00 - val_loss: 0.1252 - val_mean_squared_error: 0.1252 - val_accuracy: 0.0000e+00
# Epoch 513/3000
# 18/18 - 0s - loss: 0.1243 - mean_squared_error: 0.1243 - accuracy: 0.0000e+00 - val_loss: 0.1252 - val_mean_squared_error: 0.1252 - val_accuracy: 0.0000e+00
# Epoch 514/3000
# 18/18 - 0s - loss: 0.1243 - mean_squared_error: 0.1243 - accuracy: 0.0000e+00 - val_loss: 0.1252 - val_mean_squared_error: 0.1252 - val_accuracy: 0.0000e+00
# Epoch 515/3000
# 18/18 - 0s - loss: 0.1243 - mean_squared_error: 0.1243 - accuracy: 0.0000e+00 - val_loss: 0.1251 - val_mean_squared_error: 0.1251 - val_accuracy: 0.0000e+00
# Epoch 516/3000
# 18/18 - 0s - loss: 0.1242 - mean_squared_error: 0.1242 - accuracy: 0.0000e+00 - val_loss: 0.1251 - val_mean_squared_error: 0.1251 - val_accuracy: 0.0000e+00
# Epoch 517/3000
# 18/18 - 0s - loss: 0.1242 - mean_squared_error: 0.1242 - accuracy: 0.0000e+00 - val_loss: 0.1251 - val_mean_squared_error: 0.1251 - val_accuracy: 0.0000e+00
# Epoch 518/3000
# 18/18 - 0s - loss: 0.1242 - mean_squared_error: 0.1242 - accuracy: 0.0000e+00 - val_loss: 0.1251 - val_mean_squared_error: 0.1251 - val_accuracy: 0.0000e+00
# Epoch 519/3000
# 18/18 - 0s - loss: 0.1242 - mean_squared_error: 0.1242 - accuracy: 0.0000e+00 - val_loss: 0.1250 - val_mean_squared_error: 0.1250 - val_accuracy: 0.0000e+00
# Epoch 520/3000
# 18/18 - 0s - loss: 0.1242 - mean_squared_error: 0.1242 - accuracy: 0.0000e+00 - val_loss: 0.1250 - val_mean_squared_error: 0.1250 - val_accuracy: 0.0000e+00
# Epoch 521/3000
# 18/18 - 0s - loss: 0.1241 - mean_squared_error: 0.1241 - accuracy: 0.0000e+00 - val_loss: 0.1250 - val_mean_squared_error: 0.1250 - val_accuracy: 0.0000e+00
# Epoch 522/3000
# 18/18 - 0s - loss: 0.1241 - mean_squared_error: 0.1241 - accuracy: 0.0000e+00 - val_loss: 0.1250 - val_mean_squared_error: 0.1250 - val_accuracy: 0.0000e+00
# Epoch 523/3000
# 18/18 - 0s - loss: 0.1241 - mean_squared_error: 0.1241 - accuracy: 0.0000e+00 - val_loss: 0.1249 - val_mean_squared_error: 0.1249 - val_accuracy: 0.0000e+00
# Epoch 524/3000
# 18/18 - 0s - loss: 0.1241 - mean_squared_error: 0.1241 - accuracy: 0.0000e+00 - val_loss: 0.1249 - val_mean_squared_error: 0.1249 - val_accuracy: 0.0000e+00
# Epoch 525/3000
# 18/18 - 0s - loss: 0.1241 - mean_squared_error: 0.1241 - accuracy: 0.0000e+00 - val_loss: 0.1249 - val_mean_squared_error: 0.1249 - val_accuracy: 0.0000e+00
# Epoch 526/3000
# 18/18 - 0s - loss: 0.1240 - mean_squared_error: 0.1240 - accuracy: 0.0000e+00 - val_loss: 0.1249 - val_mean_squared_error: 0.1249 - val_accuracy: 0.0000e+00
# Epoch 527/3000
# 18/18 - 0s - loss: 0.1240 - mean_squared_error: 0.1240 - accuracy: 0.0000e+00 - val_loss: 0.1248 - val_mean_squared_error: 0.1248 - val_accuracy: 0.0000e+00
# Epoch 528/3000
# 18/18 - 0s - loss: 0.1240 - mean_squared_error: 0.1240 - accuracy: 0.0000e+00 - val_loss: 0.1248 - val_mean_squared_error: 0.1248 - val_accuracy: 0.0000e+00
# Epoch 529/3000
# 18/18 - 0s - loss: 0.1240 - mean_squared_error: 0.1240 - accuracy: 0.0000e+00 - val_loss: 0.1248 - val_mean_squared_error: 0.1248 - val_accuracy: 0.0000e+00
# Epoch 530/3000
# 18/18 - 0s - loss: 0.1239 - mean_squared_error: 0.1239 - accuracy: 0.0000e+00 - val_loss: 0.1248 - val_mean_squared_error: 0.1248 - val_accuracy: 0.0000e+00
# Epoch 531/3000
# 18/18 - 0s - loss: 0.1239 - mean_squared_error: 0.1239 - accuracy: 0.0000e+00 - val_loss: 0.1247 - val_mean_squared_error: 0.1247 - val_accuracy: 0.0000e+00
# Epoch 532/3000
# 18/18 - 0s - loss: 0.1239 - mean_squared_error: 0.1239 - accuracy: 0.0000e+00 - val_loss: 0.1247 - val_mean_squared_error: 0.1247 - val_accuracy: 0.0000e+00
# Epoch 533/3000
# 18/18 - 0s - loss: 0.1239 - mean_squared_error: 0.1239 - accuracy: 0.0000e+00 - val_loss: 0.1247 - val_mean_squared_error: 0.1247 - val_accuracy: 0.0000e+00
# Epoch 534/3000
# 18/18 - 0s - loss: 0.1239 - mean_squared_error: 0.1239 - accuracy: 0.0000e+00 - val_loss: 0.1246 - val_mean_squared_error: 0.1246 - val_accuracy: 0.0000e+00
# Epoch 535/3000
# 18/18 - 0s - loss: 0.1238 - mean_squared_error: 0.1238 - accuracy: 0.0000e+00 - val_loss: 0.1246 - val_mean_squared_error: 0.1246 - val_accuracy: 0.0000e+00
# Epoch 536/3000
# 18/18 - 0s - loss: 0.1238 - mean_squared_error: 0.1238 - accuracy: 0.0000e+00 - val_loss: 0.1246 - val_mean_squared_error: 0.1246 - val_accuracy: 0.0000e+00
# Epoch 537/3000
# 18/18 - 0s - loss: 0.1238 - mean_squared_error: 0.1238 - accuracy: 0.0000e+00 - val_loss: 0.1246 - val_mean_squared_error: 0.1246 - val_accuracy: 0.0000e+00
# Epoch 538/3000
# 18/18 - 0s - loss: 0.1238 - mean_squared_error: 0.1238 - accuracy: 0.0000e+00 - val_loss: 0.1245 - val_mean_squared_error: 0.1245 - val_accuracy: 0.0000e+00
# Epoch 539/3000
# 18/18 - 0s - loss: 0.1237 - mean_squared_error: 0.1237 - accuracy: 0.0000e+00 - val_loss: 0.1245 - val_mean_squared_error: 0.1245 - val_accuracy: 0.0000e+00
# Epoch 540/3000
# 18/18 - 0s - loss: 0.1237 - mean_squared_error: 0.1237 - accuracy: 0.0000e+00 - val_loss: 0.1245 - val_mean_squared_error: 0.1245 - val_accuracy: 0.0000e+00
# Epoch 541/3000
# 18/18 - 0s - loss: 0.1237 - mean_squared_error: 0.1237 - accuracy: 0.0000e+00 - val_loss: 0.1244 - val_mean_squared_error: 0.1244 - val_accuracy: 0.0000e+00
# Epoch 542/3000
# 18/18 - 0s - loss: 0.1237 - mean_squared_error: 0.1237 - accuracy: 0.0000e+00 - val_loss: 0.1244 - val_mean_squared_error: 0.1244 - val_accuracy: 0.0000e+00
# Epoch 543/3000
# 18/18 - 0s - loss: 0.1237 - mean_squared_error: 0.1237 - accuracy: 0.0000e+00 - val_loss: 0.1244 - val_mean_squared_error: 0.1244 - val_accuracy: 0.0000e+00
# Epoch 544/3000
# 18/18 - 0s - loss: 0.1236 - mean_squared_error: 0.1236 - accuracy: 0.0000e+00 - val_loss: 0.1244 - val_mean_squared_error: 0.1244 - val_accuracy: 0.0000e+00
# Epoch 545/3000
# 18/18 - 0s - loss: 0.1236 - mean_squared_error: 0.1236 - accuracy: 0.0000e+00 - val_loss: 0.1243 - val_mean_squared_error: 0.1243 - val_accuracy: 0.0000e+00
# Epoch 546/3000
# 18/18 - 0s - loss: 0.1236 - mean_squared_error: 0.1236 - accuracy: 0.0000e+00 - val_loss: 0.1243 - val_mean_squared_error: 0.1243 - val_accuracy: 0.0000e+00
# Epoch 547/3000
# 18/18 - 0s - loss: 0.1236 - mean_squared_error: 0.1236 - accuracy: 0.0000e+00 - val_loss: 0.1243 - val_mean_squared_error: 0.1243 - val_accuracy: 0.0000e+00
# Epoch 548/3000
# 18/18 - 0s - loss: 0.1235 - mean_squared_error: 0.1235 - accuracy: 0.0000e+00 - val_loss: 0.1243 - val_mean_squared_error: 0.1243 - val_accuracy: 0.0000e+00
# Epoch 549/3000
# 18/18 - 0s - loss: 0.1235 - mean_squared_error: 0.1235 - accuracy: 0.0000e+00 - val_loss: 0.1242 - val_mean_squared_error: 0.1242 - val_accuracy: 0.0000e+00
# Epoch 550/3000
# 18/18 - 0s - loss: 0.1235 - mean_squared_error: 0.1235 - accuracy: 0.0000e+00 - val_loss: 0.1242 - val_mean_squared_error: 0.1242 - val_accuracy: 0.0000e+00
# Epoch 551/3000
# 18/18 - 0s - loss: 0.1235 - mean_squared_error: 0.1235 - accuracy: 0.0000e+00 - val_loss: 0.1242 - val_mean_squared_error: 0.1242 - val_accuracy: 0.0000e+00
# Epoch 552/3000
# 18/18 - 0s - loss: 0.1235 - mean_squared_error: 0.1235 - accuracy: 0.0000e+00 - val_loss: 0.1241 - val_mean_squared_error: 0.1241 - val_accuracy: 0.0000e+00
# Epoch 553/3000
# 18/18 - 0s - loss: 0.1234 - mean_squared_error: 0.1234 - accuracy: 0.0000e+00 - val_loss: 0.1241 - val_mean_squared_error: 0.1241 - val_accuracy: 0.0000e+00
# Epoch 554/3000
# 18/18 - 0s - loss: 0.1234 - mean_squared_error: 0.1234 - accuracy: 0.0000e+00 - val_loss: 0.1241 - val_mean_squared_error: 0.1241 - val_accuracy: 0.0000e+00
# Epoch 555/3000
# 18/18 - 0s - loss: 0.1234 - mean_squared_error: 0.1234 - accuracy: 0.0000e+00 - val_loss: 0.1241 - val_mean_squared_error: 0.1241 - val_accuracy: 0.0000e+00
# Epoch 556/3000
# 18/18 - 0s - loss: 0.1234 - mean_squared_error: 0.1234 - accuracy: 0.0000e+00 - val_loss: 0.1240 - val_mean_squared_error: 0.1240 - val_accuracy: 0.0000e+00
# Epoch 557/3000
# 18/18 - 0s - loss: 0.1233 - mean_squared_error: 0.1233 - accuracy: 0.0000e+00 - val_loss: 0.1240 - val_mean_squared_error: 0.1240 - val_accuracy: 0.0000e+00
# Epoch 558/3000
# 18/18 - 0s - loss: 0.1233 - mean_squared_error: 0.1233 - accuracy: 0.0000e+00 - val_loss: 0.1240 - val_mean_squared_error: 0.1240 - val_accuracy: 0.0000e+00
# Epoch 559/3000
# 18/18 - 0s - loss: 0.1233 - mean_squared_error: 0.1233 - accuracy: 0.0000e+00 - val_loss: 0.1240 - val_mean_squared_error: 0.1240 - val_accuracy: 0.0000e+00
# Epoch 560/3000
# 18/18 - 0s - loss: 0.1233 - mean_squared_error: 0.1233 - accuracy: 0.0000e+00 - val_loss: 0.1239 - val_mean_squared_error: 0.1239 - val_accuracy: 0.0000e+00
# Epoch 561/3000
# 18/18 - 0s - loss: 0.1232 - mean_squared_error: 0.1232 - accuracy: 0.0000e+00 - val_loss: 0.1239 - val_mean_squared_error: 0.1239 - val_accuracy: 0.0000e+00
# Epoch 562/3000
# 18/18 - 0s - loss: 0.1232 - mean_squared_error: 0.1232 - accuracy: 0.0000e+00 - val_loss: 0.1239 - val_mean_squared_error: 0.1239 - val_accuracy: 0.0000e+00
# Epoch 563/3000
# 18/18 - 0s - loss: 0.1232 - mean_squared_error: 0.1232 - accuracy: 0.0000e+00 - val_loss: 0.1238 - val_mean_squared_error: 0.1238 - val_accuracy: 0.0000e+00
# Epoch 564/3000
# 18/18 - 0s - loss: 0.1232 - mean_squared_error: 0.1232 - accuracy: 0.0000e+00 - val_loss: 0.1238 - val_mean_squared_error: 0.1238 - val_accuracy: 0.0000e+00
# Epoch 565/3000
# 18/18 - 0s - loss: 0.1232 - mean_squared_error: 0.1232 - accuracy: 0.0000e+00 - val_loss: 0.1238 - val_mean_squared_error: 0.1238 - val_accuracy: 0.0000e+00
# Epoch 566/3000
# 18/18 - 0s - loss: 0.1231 - mean_squared_error: 0.1231 - accuracy: 0.0000e+00 - val_loss: 0.1238 - val_mean_squared_error: 0.1238 - val_accuracy: 0.0000e+00
# Epoch 567/3000
# 18/18 - 0s - loss: 0.1231 - mean_squared_error: 0.1231 - accuracy: 0.0000e+00 - val_loss: 0.1237 - val_mean_squared_error: 0.1237 - val_accuracy: 0.0000e+00
# Epoch 568/3000
# 18/18 - 0s - loss: 0.1231 - mean_squared_error: 0.1231 - accuracy: 0.0000e+00 - val_loss: 0.1237 - val_mean_squared_error: 0.1237 - val_accuracy: 0.0000e+00
# Epoch 569/3000
# 18/18 - 0s - loss: 0.1231 - mean_squared_error: 0.1231 - accuracy: 0.0000e+00 - val_loss: 0.1237 - val_mean_squared_error: 0.1237 - val_accuracy: 0.0000e+00
# Epoch 570/3000
# 18/18 - 0s - loss: 0.1230 - mean_squared_error: 0.1230 - accuracy: 0.0000e+00 - val_loss: 0.1236 - val_mean_squared_error: 0.1236 - val_accuracy: 0.0000e+00
# Epoch 571/3000
# 18/18 - 0s - loss: 0.1230 - mean_squared_error: 0.1230 - accuracy: 0.0000e+00 - val_loss: 0.1236 - val_mean_squared_error: 0.1236 - val_accuracy: 0.0000e+00
# Epoch 572/3000
# 18/18 - 0s - loss: 0.1230 - mean_squared_error: 0.1230 - accuracy: 0.0000e+00 - val_loss: 0.1236 - val_mean_squared_error: 0.1236 - val_accuracy: 0.0000e+00
# Epoch 573/3000
# 18/18 - 0s - loss: 0.1230 - mean_squared_error: 0.1230 - accuracy: 0.0000e+00 - val_loss: 0.1236 - val_mean_squared_error: 0.1236 - val_accuracy: 0.0000e+00
# Epoch 574/3000
# 18/18 - 0s - loss: 0.1229 - mean_squared_error: 0.1229 - accuracy: 0.0000e+00 - val_loss: 0.1235 - val_mean_squared_error: 0.1235 - val_accuracy: 0.0000e+00
# Epoch 575/3000
# 18/18 - 0s - loss: 0.1229 - mean_squared_error: 0.1229 - accuracy: 0.0000e+00 - val_loss: 0.1235 - val_mean_squared_error: 0.1235 - val_accuracy: 0.0000e+00
# Epoch 576/3000
# 18/18 - 0s - loss: 0.1229 - mean_squared_error: 0.1229 - accuracy: 0.0000e+00 - val_loss: 0.1235 - val_mean_squared_error: 0.1235 - val_accuracy: 0.0000e+00
# Epoch 577/3000
# 18/18 - 0s - loss: 0.1229 - mean_squared_error: 0.1229 - accuracy: 0.0000e+00 - val_loss: 0.1234 - val_mean_squared_error: 0.1234 - val_accuracy: 0.0000e+00
# Epoch 578/3000
# 18/18 - 0s - loss: 0.1228 - mean_squared_error: 0.1228 - accuracy: 0.0000e+00 - val_loss: 0.1234 - val_mean_squared_error: 0.1234 - val_accuracy: 0.0000e+00
# Epoch 579/3000
# 18/18 - 0s - loss: 0.1228 - mean_squared_error: 0.1228 - accuracy: 0.0000e+00 - val_loss: 0.1234 - val_mean_squared_error: 0.1234 - val_accuracy: 0.0000e+00
# Epoch 580/3000
# 18/18 - 0s - loss: 0.1228 - mean_squared_error: 0.1228 - accuracy: 0.0000e+00 - val_loss: 0.1233 - val_mean_squared_error: 0.1233 - val_accuracy: 0.0000e+00
# Epoch 581/3000
# 18/18 - 0s - loss: 0.1228 - mean_squared_error: 0.1228 - accuracy: 0.0000e+00 - val_loss: 0.1233 - val_mean_squared_error: 0.1233 - val_accuracy: 0.0000e+00
# Epoch 582/3000
# 18/18 - 0s - loss: 0.1228 - mean_squared_error: 0.1228 - accuracy: 0.0000e+00 - val_loss: 0.1233 - val_mean_squared_error: 0.1233 - val_accuracy: 0.0000e+00
# Epoch 583/3000
# 18/18 - 0s - loss: 0.1227 - mean_squared_error: 0.1227 - accuracy: 0.0000e+00 - val_loss: 0.1233 - val_mean_squared_error: 0.1233 - val_accuracy: 0.0000e+00
# Epoch 584/3000
# 18/18 - 0s - loss: 0.1227 - mean_squared_error: 0.1227 - accuracy: 0.0000e+00 - val_loss: 0.1233 - val_mean_squared_error: 0.1233 - val_accuracy: 0.0000e+00
# Epoch 585/3000
# 18/18 - 0s - loss: 0.1227 - mean_squared_error: 0.1227 - accuracy: 0.0000e+00 - val_loss: 0.1232 - val_mean_squared_error: 0.1232 - val_accuracy: 0.0000e+00
# Epoch 586/3000
# 18/18 - 0s - loss: 0.1227 - mean_squared_error: 0.1227 - accuracy: 0.0000e+00 - val_loss: 0.1232 - val_mean_squared_error: 0.1232 - val_accuracy: 0.0000e+00
# Epoch 587/3000
# 18/18 - 0s - loss: 0.1226 - mean_squared_error: 0.1226 - accuracy: 0.0000e+00 - val_loss: 0.1232 - val_mean_squared_error: 0.1232 - val_accuracy: 0.0000e+00
# Epoch 588/3000
# 18/18 - 0s - loss: 0.1226 - mean_squared_error: 0.1226 - accuracy: 0.0000e+00 - val_loss: 0.1231 - val_mean_squared_error: 0.1231 - val_accuracy: 0.0000e+00
# Epoch 589/3000
# 18/18 - 0s - loss: 0.1226 - mean_squared_error: 0.1226 - accuracy: 0.0000e+00 - val_loss: 0.1231 - val_mean_squared_error: 0.1231 - val_accuracy: 0.0000e+00
# Epoch 590/3000
# 18/18 - 0s - loss: 0.1226 - mean_squared_error: 0.1226 - accuracy: 0.0000e+00 - val_loss: 0.1231 - val_mean_squared_error: 0.1231 - val_accuracy: 0.0000e+00
# Epoch 591/3000
# 18/18 - 0s - loss: 0.1225 - mean_squared_error: 0.1225 - accuracy: 0.0000e+00 - val_loss: 0.1230 - val_mean_squared_error: 0.1230 - val_accuracy: 0.0000e+00
# Epoch 592/3000
# 18/18 - 0s - loss: 0.1225 - mean_squared_error: 0.1225 - accuracy: 0.0000e+00 - val_loss: 0.1230 - val_mean_squared_error: 0.1230 - val_accuracy: 0.0000e+00
# Epoch 593/3000
# 18/18 - 0s - loss: 0.1225 - mean_squared_error: 0.1225 - accuracy: 0.0000e+00 - val_loss: 0.1230 - val_mean_squared_error: 0.1230 - val_accuracy: 0.0000e+00
# Epoch 594/3000
# 18/18 - 0s - loss: 0.1225 - mean_squared_error: 0.1225 - accuracy: 0.0000e+00 - val_loss: 0.1230 - val_mean_squared_error: 0.1230 - val_accuracy: 0.0000e+00
# Epoch 595/3000
# 18/18 - 0s - loss: 0.1224 - mean_squared_error: 0.1224 - accuracy: 0.0000e+00 - val_loss: 0.1229 - val_mean_squared_error: 0.1229 - val_accuracy: 0.0000e+00
# Epoch 596/3000
# 18/18 - 0s - loss: 0.1224 - mean_squared_error: 0.1224 - accuracy: 0.0000e+00 - val_loss: 0.1229 - val_mean_squared_error: 0.1229 - val_accuracy: 0.0000e+00
# Epoch 597/3000
# 18/18 - 0s - loss: 0.1224 - mean_squared_error: 0.1224 - accuracy: 0.0000e+00 - val_loss: 0.1229 - val_mean_squared_error: 0.1229 - val_accuracy: 0.0000e+00
# Epoch 598/3000
# 18/18 - 0s - loss: 0.1224 - mean_squared_error: 0.1224 - accuracy: 0.0000e+00 - val_loss: 0.1229 - val_mean_squared_error: 0.1229 - val_accuracy: 0.0000e+00
# Epoch 599/3000
# 18/18 - 0s - loss: 0.1223 - mean_squared_error: 0.1223 - accuracy: 0.0000e+00 - val_loss: 0.1228 - val_mean_squared_error: 0.1228 - val_accuracy: 0.0000e+00
# Epoch 600/3000
# 18/18 - 0s - loss: 0.1223 - mean_squared_error: 0.1223 - accuracy: 0.0000e+00 - val_loss: 0.1228 - val_mean_squared_error: 0.1228 - val_accuracy: 0.0000e+00
# Epoch 601/3000
# 18/18 - 0s - loss: 0.1223 - mean_squared_error: 0.1223 - accuracy: 0.0000e+00 - val_loss: 0.1228 - val_mean_squared_error: 0.1228 - val_accuracy: 0.0000e+00
# Epoch 602/3000
# 18/18 - 0s - loss: 0.1223 - mean_squared_error: 0.1223 - accuracy: 0.0000e+00 - val_loss: 0.1227 - val_mean_squared_error: 0.1227 - val_accuracy: 0.0000e+00
# Epoch 603/3000
# 18/18 - 0s - loss: 0.1222 - mean_squared_error: 0.1222 - accuracy: 0.0000e+00 - val_loss: 0.1227 - val_mean_squared_error: 0.1227 - val_accuracy: 0.0000e+00
# Epoch 604/3000
# 18/18 - 0s - loss: 0.1222 - mean_squared_error: 0.1222 - accuracy: 0.0000e+00 - val_loss: 0.1227 - val_mean_squared_error: 0.1227 - val_accuracy: 0.0000e+00
# Epoch 605/3000
# 18/18 - 0s - loss: 0.1222 - mean_squared_error: 0.1222 - accuracy: 0.0000e+00 - val_loss: 0.1226 - val_mean_squared_error: 0.1226 - val_accuracy: 0.0000e+00
# Epoch 606/3000
# 18/18 - 0s - loss: 0.1222 - mean_squared_error: 0.1222 - accuracy: 0.0000e+00 - val_loss: 0.1226 - val_mean_squared_error: 0.1226 - val_accuracy: 0.0000e+00
# Epoch 607/3000
# 18/18 - 0s - loss: 0.1221 - mean_squared_error: 0.1221 - accuracy: 0.0000e+00 - val_loss: 0.1226 - val_mean_squared_error: 0.1226 - val_accuracy: 0.0000e+00
# Epoch 608/3000
# 18/18 - 0s - loss: 0.1221 - mean_squared_error: 0.1221 - accuracy: 0.0000e+00 - val_loss: 0.1226 - val_mean_squared_error: 0.1226 - val_accuracy: 0.0000e+00
# Epoch 609/3000
# 18/18 - 0s - loss: 0.1221 - mean_squared_error: 0.1221 - accuracy: 0.0000e+00 - val_loss: 0.1225 - val_mean_squared_error: 0.1225 - val_accuracy: 0.0000e+00
# Epoch 610/3000
# 18/18 - 0s - loss: 0.1221 - mean_squared_error: 0.1221 - accuracy: 0.0000e+00 - val_loss: 0.1225 - val_mean_squared_error: 0.1225 - val_accuracy: 0.0000e+00
# Epoch 611/3000
# 18/18 - 0s - loss: 0.1220 - mean_squared_error: 0.1220 - accuracy: 0.0000e+00 - val_loss: 0.1224 - val_mean_squared_error: 0.1224 - val_accuracy: 0.0000e+00
# Epoch 612/3000
# 18/18 - 0s - loss: 0.1220 - mean_squared_error: 0.1220 - accuracy: 0.0000e+00 - val_loss: 0.1224 - val_mean_squared_error: 0.1224 - val_accuracy: 0.0000e+00
# Epoch 613/3000
# 18/18 - 0s - loss: 0.1220 - mean_squared_error: 0.1220 - accuracy: 0.0000e+00 - val_loss: 0.1224 - val_mean_squared_error: 0.1224 - val_accuracy: 0.0000e+00
# Epoch 614/3000
# 18/18 - 0s - loss: 0.1220 - mean_squared_error: 0.1220 - accuracy: 0.0000e+00 - val_loss: 0.1224 - val_mean_squared_error: 0.1224 - val_accuracy: 0.0000e+00
# Epoch 615/3000
# 18/18 - 0s - loss: 0.1219 - mean_squared_error: 0.1219 - accuracy: 0.0000e+00 - val_loss: 0.1223 - val_mean_squared_error: 0.1223 - val_accuracy: 0.0000e+00
# Epoch 616/3000
# 18/18 - 0s - loss: 0.1219 - mean_squared_error: 0.1219 - accuracy: 0.0000e+00 - val_loss: 0.1223 - val_mean_squared_error: 0.1223 - val_accuracy: 0.0000e+00
# Epoch 617/3000
# 18/18 - 0s - loss: 0.1219 - mean_squared_error: 0.1219 - accuracy: 0.0000e+00 - val_loss: 0.1223 - val_mean_squared_error: 0.1223 - val_accuracy: 0.0000e+00
# Epoch 618/3000
# 18/18 - 0s - loss: 0.1219 - mean_squared_error: 0.1219 - accuracy: 0.0000e+00 - val_loss: 0.1222 - val_mean_squared_error: 0.1222 - val_accuracy: 0.0000e+00
# Epoch 619/3000
# 18/18 - 0s - loss: 0.1218 - mean_squared_error: 0.1218 - accuracy: 0.0000e+00 - val_loss: 0.1222 - val_mean_squared_error: 0.1222 - val_accuracy: 0.0000e+00
# Epoch 620/3000
# 18/18 - 0s - loss: 0.1218 - mean_squared_error: 0.1218 - accuracy: 0.0000e+00 - val_loss: 0.1222 - val_mean_squared_error: 0.1222 - val_accuracy: 0.0000e+00
# Epoch 621/3000
# 18/18 - 0s - loss: 0.1218 - mean_squared_error: 0.1218 - accuracy: 0.0000e+00 - val_loss: 0.1222 - val_mean_squared_error: 0.1222 - val_accuracy: 0.0000e+00
# Epoch 622/3000
# 18/18 - 0s - loss: 0.1218 - mean_squared_error: 0.1218 - accuracy: 0.0000e+00 - val_loss: 0.1221 - val_mean_squared_error: 0.1221 - val_accuracy: 0.0000e+00
# Epoch 623/3000
# 18/18 - 0s - loss: 0.1217 - mean_squared_error: 0.1217 - accuracy: 0.0000e+00 - val_loss: 0.1221 - val_mean_squared_error: 0.1221 - val_accuracy: 0.0000e+00
# Epoch 624/3000
# 18/18 - 0s - loss: 0.1217 - mean_squared_error: 0.1217 - accuracy: 0.0000e+00 - val_loss: 0.1220 - val_mean_squared_error: 0.1220 - val_accuracy: 0.0000e+00
# Epoch 625/3000
# 18/18 - 0s - loss: 0.1217 - mean_squared_error: 0.1217 - accuracy: 0.0000e+00 - val_loss: 0.1220 - val_mean_squared_error: 0.1220 - val_accuracy: 0.0000e+00
# Epoch 626/3000
# 18/18 - 0s - loss: 0.1217 - mean_squared_error: 0.1217 - accuracy: 0.0000e+00 - val_loss: 0.1220 - val_mean_squared_error: 0.1220 - val_accuracy: 0.0000e+00
# Epoch 627/3000
# 18/18 - 0s - loss: 0.1216 - mean_squared_error: 0.1216 - accuracy: 0.0000e+00 - val_loss: 0.1220 - val_mean_squared_error: 0.1220 - val_accuracy: 0.0000e+00
# Epoch 628/3000
# 18/18 - 0s - loss: 0.1216 - mean_squared_error: 0.1216 - accuracy: 0.0000e+00 - val_loss: 0.1219 - val_mean_squared_error: 0.1219 - val_accuracy: 0.0000e+00
# Epoch 629/3000
# 18/18 - 0s - loss: 0.1216 - mean_squared_error: 0.1216 - accuracy: 0.0000e+00 - val_loss: 0.1219 - val_mean_squared_error: 0.1219 - val_accuracy: 0.0000e+00
# Epoch 630/3000
# 18/18 - 0s - loss: 0.1216 - mean_squared_error: 0.1216 - accuracy: 0.0000e+00 - val_loss: 0.1219 - val_mean_squared_error: 0.1219 - val_accuracy: 0.0000e+00
# Epoch 631/3000
# 18/18 - 0s - loss: 0.1215 - mean_squared_error: 0.1215 - accuracy: 0.0000e+00 - val_loss: 0.1218 - val_mean_squared_error: 0.1218 - val_accuracy: 0.0000e+00
# Epoch 632/3000
# 18/18 - 0s - loss: 0.1215 - mean_squared_error: 0.1215 - accuracy: 0.0000e+00 - val_loss: 0.1218 - val_mean_squared_error: 0.1218 - val_accuracy: 0.0000e+00
# Epoch 633/3000
# 18/18 - 0s - loss: 0.1215 - mean_squared_error: 0.1215 - accuracy: 0.0000e+00 - val_loss: 0.1218 - val_mean_squared_error: 0.1218 - val_accuracy: 0.0000e+00
# Epoch 634/3000
# 18/18 - 0s - loss: 0.1215 - mean_squared_error: 0.1215 - accuracy: 0.0000e+00 - val_loss: 0.1217 - val_mean_squared_error: 0.1217 - val_accuracy: 0.0000e+00
# Epoch 635/3000
# 18/18 - 0s - loss: 0.1214 - mean_squared_error: 0.1214 - accuracy: 0.0000e+00 - val_loss: 0.1217 - val_mean_squared_error: 0.1217 - val_accuracy: 0.0000e+00
# Epoch 636/3000
# 18/18 - 0s - loss: 0.1214 - mean_squared_error: 0.1214 - accuracy: 0.0000e+00 - val_loss: 0.1217 - val_mean_squared_error: 0.1217 - val_accuracy: 0.0000e+00
# Epoch 637/3000
# 18/18 - 0s - loss: 0.1214 - mean_squared_error: 0.1214 - accuracy: 0.0000e+00 - val_loss: 0.1217 - val_mean_squared_error: 0.1217 - val_accuracy: 0.0000e+00
# Epoch 638/3000
# 18/18 - 0s - loss: 0.1214 - mean_squared_error: 0.1214 - accuracy: 0.0000e+00 - val_loss: 0.1216 - val_mean_squared_error: 0.1216 - val_accuracy: 0.0000e+00
# Epoch 639/3000
# 18/18 - 0s - loss: 0.1213 - mean_squared_error: 0.1213 - accuracy: 0.0000e+00 - val_loss: 0.1216 - val_mean_squared_error: 0.1216 - val_accuracy: 0.0000e+00
# Epoch 640/3000
# 18/18 - 0s - loss: 0.1213 - mean_squared_error: 0.1213 - accuracy: 0.0000e+00 - val_loss: 0.1216 - val_mean_squared_error: 0.1216 - val_accuracy: 0.0000e+00
# Epoch 641/3000
# 18/18 - 0s - loss: 0.1213 - mean_squared_error: 0.1213 - accuracy: 0.0000e+00 - val_loss: 0.1215 - val_mean_squared_error: 0.1215 - val_accuracy: 0.0000e+00
# Epoch 642/3000
# 18/18 - 0s - loss: 0.1213 - mean_squared_error: 0.1213 - accuracy: 0.0000e+00 - val_loss: 0.1215 - val_mean_squared_error: 0.1215 - val_accuracy: 0.0000e+00
# Epoch 643/3000
# 18/18 - 0s - loss: 0.1212 - mean_squared_error: 0.1212 - accuracy: 0.0000e+00 - val_loss: 0.1215 - val_mean_squared_error: 0.1215 - val_accuracy: 0.0000e+00
# Epoch 644/3000
# 18/18 - 0s - loss: 0.1212 - mean_squared_error: 0.1212 - accuracy: 0.0000e+00 - val_loss: 0.1215 - val_mean_squared_error: 0.1215 - val_accuracy: 0.0000e+00
# Epoch 645/3000
# 18/18 - 0s - loss: 0.1212 - mean_squared_error: 0.1212 - accuracy: 0.0000e+00 - val_loss: 0.1214 - val_mean_squared_error: 0.1214 - val_accuracy: 0.0000e+00
# Epoch 646/3000
# 18/18 - 0s - loss: 0.1211 - mean_squared_error: 0.1211 - accuracy: 0.0000e+00 - val_loss: 0.1214 - val_mean_squared_error: 0.1214 - val_accuracy: 0.0000e+00
# Epoch 647/3000
# 18/18 - 0s - loss: 0.1211 - mean_squared_error: 0.1211 - accuracy: 0.0000e+00 - val_loss: 0.1214 - val_mean_squared_error: 0.1214 - val_accuracy: 0.0000e+00
# Epoch 648/3000
# 18/18 - 0s - loss: 0.1211 - mean_squared_error: 0.1211 - accuracy: 0.0000e+00 - val_loss: 0.1213 - val_mean_squared_error: 0.1213 - val_accuracy: 0.0000e+00
# Epoch 649/3000
# 18/18 - 0s - loss: 0.1211 - mean_squared_error: 0.1211 - accuracy: 0.0000e+00 - val_loss: 0.1213 - val_mean_squared_error: 0.1213 - val_accuracy: 0.0000e+00
# Epoch 650/3000
# 18/18 - 0s - loss: 0.1210 - mean_squared_error: 0.1210 - accuracy: 0.0000e+00 - val_loss: 0.1213 - val_mean_squared_error: 0.1213 - val_accuracy: 0.0000e+00
# Epoch 651/3000
# 18/18 - 0s - loss: 0.1210 - mean_squared_error: 0.1210 - accuracy: 0.0000e+00 - val_loss: 0.1212 - val_mean_squared_error: 0.1212 - val_accuracy: 0.0000e+00
# Epoch 652/3000
# 18/18 - 0s - loss: 0.1210 - mean_squared_error: 0.1210 - accuracy: 0.0000e+00 - val_loss: 0.1212 - val_mean_squared_error: 0.1212 - val_accuracy: 0.0000e+00
# Epoch 653/3000
# 18/18 - 0s - loss: 0.1210 - mean_squared_error: 0.1210 - accuracy: 0.0000e+00 - val_loss: 0.1212 - val_mean_squared_error: 0.1212 - val_accuracy: 0.0000e+00
# Epoch 654/3000
# 18/18 - 0s - loss: 0.1209 - mean_squared_error: 0.1209 - accuracy: 0.0000e+00 - val_loss: 0.1211 - val_mean_squared_error: 0.1211 - val_accuracy: 0.0000e+00
# Epoch 655/3000
# 18/18 - 0s - loss: 0.1209 - mean_squared_error: 0.1209 - accuracy: 0.0000e+00 - val_loss: 0.1211 - val_mean_squared_error: 0.1211 - val_accuracy: 0.0000e+00
# Epoch 656/3000
# 18/18 - 0s - loss: 0.1209 - mean_squared_error: 0.1209 - accuracy: 0.0000e+00 - val_loss: 0.1211 - val_mean_squared_error: 0.1211 - val_accuracy: 0.0000e+00
# Epoch 657/3000
# 18/18 - 0s - loss: 0.1209 - mean_squared_error: 0.1209 - accuracy: 0.0000e+00 - val_loss: 0.1210 - val_mean_squared_error: 0.1210 - val_accuracy: 0.0000e+00
# Epoch 658/3000
# 18/18 - 0s - loss: 0.1208 - mean_squared_error: 0.1208 - accuracy: 0.0000e+00 - val_loss: 0.1210 - val_mean_squared_error: 0.1210 - val_accuracy: 0.0000e+00
# Epoch 659/3000
# 18/18 - 0s - loss: 0.1208 - mean_squared_error: 0.1208 - accuracy: 0.0000e+00 - val_loss: 0.1210 - val_mean_squared_error: 0.1210 - val_accuracy: 0.0000e+00
# Epoch 660/3000
# 18/18 - 0s - loss: 0.1208 - mean_squared_error: 0.1208 - accuracy: 0.0000e+00 - val_loss: 0.1209 - val_mean_squared_error: 0.1209 - val_accuracy: 0.0000e+00
# Epoch 661/3000
# 18/18 - 0s - loss: 0.1207 - mean_squared_error: 0.1207 - accuracy: 0.0000e+00 - val_loss: 0.1209 - val_mean_squared_error: 0.1209 - val_accuracy: 0.0000e+00
# Epoch 662/3000
# 18/18 - 0s - loss: 0.1207 - mean_squared_error: 0.1207 - accuracy: 0.0000e+00 - val_loss: 0.1209 - val_mean_squared_error: 0.1209 - val_accuracy: 0.0000e+00
# Epoch 663/3000
# 18/18 - 0s - loss: 0.1207 - mean_squared_error: 0.1207 - accuracy: 0.0000e+00 - val_loss: 0.1208 - val_mean_squared_error: 0.1208 - val_accuracy: 0.0000e+00
# Epoch 664/3000
# 18/18 - 0s - loss: 0.1207 - mean_squared_error: 0.1207 - accuracy: 0.0000e+00 - val_loss: 0.1208 - val_mean_squared_error: 0.1208 - val_accuracy: 0.0000e+00
# Epoch 665/3000
# 18/18 - 0s - loss: 0.1206 - mean_squared_error: 0.1206 - accuracy: 0.0000e+00 - val_loss: 0.1208 - val_mean_squared_error: 0.1208 - val_accuracy: 0.0000e+00
# Epoch 666/3000
# 18/18 - 0s - loss: 0.1206 - mean_squared_error: 0.1206 - accuracy: 0.0000e+00 - val_loss: 0.1208 - val_mean_squared_error: 0.1208 - val_accuracy: 0.0000e+00
# Epoch 667/3000
# 18/18 - 0s - loss: 0.1206 - mean_squared_error: 0.1206 - accuracy: 0.0000e+00 - val_loss: 0.1207 - val_mean_squared_error: 0.1207 - val_accuracy: 0.0000e+00
# Epoch 668/3000
# 18/18 - 0s - loss: 0.1206 - mean_squared_error: 0.1206 - accuracy: 0.0000e+00 - val_loss: 0.1207 - val_mean_squared_error: 0.1207 - val_accuracy: 0.0000e+00
# Epoch 669/3000
# 18/18 - 0s - loss: 0.1205 - mean_squared_error: 0.1205 - accuracy: 0.0000e+00 - val_loss: 0.1206 - val_mean_squared_error: 0.1206 - val_accuracy: 0.0000e+00
# Epoch 670/3000
# 18/18 - 0s - loss: 0.1205 - mean_squared_error: 0.1205 - accuracy: 0.0000e+00 - val_loss: 0.1206 - val_mean_squared_error: 0.1206 - val_accuracy: 0.0000e+00
# Epoch 671/3000
# 18/18 - 0s - loss: 0.1205 - mean_squared_error: 0.1205 - accuracy: 0.0000e+00 - val_loss: 0.1206 - val_mean_squared_error: 0.1206 - val_accuracy: 0.0000e+00
# Epoch 672/3000
# 18/18 - 0s - loss: 0.1204 - mean_squared_error: 0.1204 - accuracy: 0.0000e+00 - val_loss: 0.1205 - val_mean_squared_error: 0.1205 - val_accuracy: 0.0000e+00
# Epoch 673/3000
# 18/18 - 0s - loss: 0.1204 - mean_squared_error: 0.1204 - accuracy: 0.0000e+00 - val_loss: 0.1205 - val_mean_squared_error: 0.1205 - val_accuracy: 0.0000e+00
# Epoch 674/3000
# 18/18 - 0s - loss: 0.1204 - mean_squared_error: 0.1204 - accuracy: 0.0000e+00 - val_loss: 0.1205 - val_mean_squared_error: 0.1205 - val_accuracy: 0.0000e+00
# Epoch 675/3000
# 18/18 - 0s - loss: 0.1204 - mean_squared_error: 0.1204 - accuracy: 0.0000e+00 - val_loss: 0.1204 - val_mean_squared_error: 0.1204 - val_accuracy: 0.0000e+00
# Epoch 676/3000
# 18/18 - 0s - loss: 0.1203 - mean_squared_error: 0.1203 - accuracy: 0.0000e+00 - val_loss: 0.1204 - val_mean_squared_error: 0.1204 - val_accuracy: 0.0000e+00
# Epoch 677/3000
# 18/18 - 0s - loss: 0.1203 - mean_squared_error: 0.1203 - accuracy: 0.0000e+00 - val_loss: 0.1204 - val_mean_squared_error: 0.1204 - val_accuracy: 0.0000e+00
# Epoch 678/3000
# 18/18 - 0s - loss: 0.1203 - mean_squared_error: 0.1203 - accuracy: 0.0000e+00 - val_loss: 0.1203 - val_mean_squared_error: 0.1203 - val_accuracy: 0.0000e+00
# Epoch 679/3000
# 18/18 - 0s - loss: 0.1203 - mean_squared_error: 0.1203 - accuracy: 0.0000e+00 - val_loss: 0.1203 - val_mean_squared_error: 0.1203 - val_accuracy: 0.0000e+00
# Epoch 680/3000
# 18/18 - 0s - loss: 0.1202 - mean_squared_error: 0.1202 - accuracy: 0.0000e+00 - val_loss: 0.1203 - val_mean_squared_error: 0.1203 - val_accuracy: 0.0000e+00
# Epoch 681/3000
# 18/18 - 0s - loss: 0.1202 - mean_squared_error: 0.1202 - accuracy: 0.0000e+00 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - val_accuracy: 0.0000e+00
# Epoch 682/3000
# 18/18 - 0s - loss: 0.1202 - mean_squared_error: 0.1202 - accuracy: 0.0000e+00 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - val_accuracy: 0.0000e+00
# Epoch 683/3000
# 18/18 - 0s - loss: 0.1202 - mean_squared_error: 0.1202 - accuracy: 0.0000e+00 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - val_accuracy: 0.0000e+00
# Epoch 684/3000
# 18/18 - 0s - loss: 0.1201 - mean_squared_error: 0.1201 - accuracy: 0.0000e+00 - val_loss: 0.1201 - val_mean_squared_error: 0.1201 - val_accuracy: 0.0000e+00
# Epoch 685/3000
# 18/18 - 0s - loss: 0.1201 - mean_squared_error: 0.1201 - accuracy: 0.0000e+00 - val_loss: 0.1201 - val_mean_squared_error: 0.1201 - val_accuracy: 0.0000e+00
# Epoch 686/3000
# 18/18 - 0s - loss: 0.1201 - mean_squared_error: 0.1201 - accuracy: 0.0000e+00 - val_loss: 0.1201 - val_mean_squared_error: 0.1201 - val_accuracy: 0.0000e+00
# Epoch 687/3000
# 18/18 - 0s - loss: 0.1200 - mean_squared_error: 0.1200 - accuracy: 0.0000e+00 - val_loss: 0.1200 - val_mean_squared_error: 0.1200 - val_accuracy: 0.0000e+00
# Epoch 688/3000
# 18/18 - 0s - loss: 0.1200 - mean_squared_error: 0.1200 - accuracy: 0.0000e+00 - val_loss: 0.1200 - val_mean_squared_error: 0.1200 - val_accuracy: 0.0000e+00
# Epoch 689/3000
# 18/18 - 0s - loss: 0.1200 - mean_squared_error: 0.1200 - accuracy: 0.0000e+00 - val_loss: 0.1200 - val_mean_squared_error: 0.1200 - val_accuracy: 0.0000e+00
# Epoch 690/3000
# 18/18 - 0s - loss: 0.1200 - mean_squared_error: 0.1200 - accuracy: 0.0000e+00 - val_loss: 0.1200 - val_mean_squared_error: 0.1200 - val_accuracy: 0.0000e+00
# Epoch 691/3000
# 18/18 - 0s - loss: 0.1199 - mean_squared_error: 0.1199 - accuracy: 0.0000e+00 - val_loss: 0.1199 - val_mean_squared_error: 0.1199 - val_accuracy: 0.0000e+00
# Epoch 692/3000
# 18/18 - 0s - loss: 0.1199 - mean_squared_error: 0.1199 - accuracy: 0.0000e+00 - val_loss: 0.1199 - val_mean_squared_error: 0.1199 - val_accuracy: 0.0000e+00
# Epoch 693/3000
# 18/18 - 0s - loss: 0.1199 - mean_squared_error: 0.1199 - accuracy: 0.0000e+00 - val_loss: 0.1198 - val_mean_squared_error: 0.1198 - val_accuracy: 0.0000e+00
# Epoch 694/3000
# 18/18 - 0s - loss: 0.1198 - mean_squared_error: 0.1198 - accuracy: 0.0000e+00 - val_loss: 0.1198 - val_mean_squared_error: 0.1198 - val_accuracy: 0.0000e+00
# Epoch 695/3000
# 18/18 - 0s - loss: 0.1198 - mean_squared_error: 0.1198 - accuracy: 0.0000e+00 - val_loss: 0.1198 - val_mean_squared_error: 0.1198 - val_accuracy: 0.0000e+00
# Epoch 696/3000
# 18/18 - 0s - loss: 0.1198 - mean_squared_error: 0.1198 - accuracy: 0.0000e+00 - val_loss: 0.1198 - val_mean_squared_error: 0.1198 - val_accuracy: 0.0000e+00
# Epoch 697/3000
# 18/18 - 0s - loss: 0.1198 - mean_squared_error: 0.1198 - accuracy: 0.0000e+00 - val_loss: 0.1197 - val_mean_squared_error: 0.1197 - val_accuracy: 0.0000e+00
# Epoch 698/3000
# 18/18 - 0s - loss: 0.1197 - mean_squared_error: 0.1197 - accuracy: 0.0000e+00 - val_loss: 0.1197 - val_mean_squared_error: 0.1197 - val_accuracy: 0.0000e+00
# Epoch 699/3000
# 18/18 - 0s - loss: 0.1197 - mean_squared_error: 0.1197 - accuracy: 0.0000e+00 - val_loss: 0.1196 - val_mean_squared_error: 0.1196 - val_accuracy: 0.0000e+00
# Epoch 700/3000
# 18/18 - 0s - loss: 0.1197 - mean_squared_error: 0.1197 - accuracy: 0.0000e+00 - val_loss: 0.1196 - val_mean_squared_error: 0.1196 - val_accuracy: 0.0000e+00
# Epoch 701/3000
# 18/18 - 0s - loss: 0.1196 - mean_squared_error: 0.1196 - accuracy: 0.0000e+00 - val_loss: 0.1196 - val_mean_squared_error: 0.1196 - val_accuracy: 0.0000e+00
# Epoch 702/3000
# 18/18 - 0s - loss: 0.1196 - mean_squared_error: 0.1196 - accuracy: 0.0000e+00 - val_loss: 0.1195 - val_mean_squared_error: 0.1195 - val_accuracy: 0.0000e+00
# Epoch 703/3000
# 18/18 - 0s - loss: 0.1196 - mean_squared_error: 0.1196 - accuracy: 0.0000e+00 - val_loss: 0.1195 - val_mean_squared_error: 0.1195 - val_accuracy: 0.0000e+00
# Epoch 704/3000
# 18/18 - 0s - loss: 0.1196 - mean_squared_error: 0.1196 - accuracy: 0.0000e+00 - val_loss: 0.1195 - val_mean_squared_error: 0.1195 - val_accuracy: 0.0000e+00
# Epoch 705/3000
# 18/18 - 0s - loss: 0.1195 - mean_squared_error: 0.1195 - accuracy: 0.0000e+00 - val_loss: 0.1194 - val_mean_squared_error: 0.1194 - val_accuracy: 0.0000e+00
# Epoch 706/3000
# 18/18 - 0s - loss: 0.1195 - mean_squared_error: 0.1195 - accuracy: 0.0000e+00 - val_loss: 0.1194 - val_mean_squared_error: 0.1194 - val_accuracy: 0.0000e+00
# Epoch 707/3000
# 18/18 - 0s - loss: 0.1195 - mean_squared_error: 0.1195 - accuracy: 0.0000e+00 - val_loss: 0.1194 - val_mean_squared_error: 0.1194 - val_accuracy: 0.0000e+00
# Epoch 708/3000
# 18/18 - 0s - loss: 0.1194 - mean_squared_error: 0.1194 - accuracy: 0.0000e+00 - val_loss: 0.1193 - val_mean_squared_error: 0.1193 - val_accuracy: 0.0000e+00
# Epoch 709/3000
# 18/18 - 0s - loss: 0.1194 - mean_squared_error: 0.1194 - accuracy: 0.0000e+00 - val_loss: 0.1193 - val_mean_squared_error: 0.1193 - val_accuracy: 0.0000e+00
# Epoch 710/3000
# 18/18 - 0s - loss: 0.1194 - mean_squared_error: 0.1194 - accuracy: 0.0000e+00 - val_loss: 0.1193 - val_mean_squared_error: 0.1193 - val_accuracy: 0.0000e+00
# Epoch 711/3000
# 18/18 - 0s - loss: 0.1193 - mean_squared_error: 0.1193 - accuracy: 0.0000e+00 - val_loss: 0.1192 - val_mean_squared_error: 0.1192 - val_accuracy: 0.0000e+00
# Epoch 712/3000
# 18/18 - 0s - loss: 0.1193 - mean_squared_error: 0.1193 - accuracy: 0.0000e+00 - val_loss: 0.1192 - val_mean_squared_error: 0.1192 - val_accuracy: 0.0000e+00
# Epoch 713/3000
# 18/18 - 0s - loss: 0.1193 - mean_squared_error: 0.1193 - accuracy: 0.0000e+00 - val_loss: 0.1192 - val_mean_squared_error: 0.1192 - val_accuracy: 0.0000e+00
# Epoch 714/3000
# 18/18 - 0s - loss: 0.1193 - mean_squared_error: 0.1193 - accuracy: 0.0000e+00 - val_loss: 0.1191 - val_mean_squared_error: 0.1191 - val_accuracy: 0.0000e+00
# Epoch 715/3000
# 18/18 - 0s - loss: 0.1192 - mean_squared_error: 0.1192 - accuracy: 0.0000e+00 - val_loss: 0.1191 - val_mean_squared_error: 0.1191 - val_accuracy: 0.0000e+00
# Epoch 716/3000
# 18/18 - 0s - loss: 0.1192 - mean_squared_error: 0.1192 - accuracy: 0.0000e+00 - val_loss: 0.1191 - val_mean_squared_error: 0.1191 - val_accuracy: 0.0000e+00
# Epoch 717/3000
# 18/18 - 0s - loss: 0.1192 - mean_squared_error: 0.1192 - accuracy: 0.0000e+00 - val_loss: 0.1190 - val_mean_squared_error: 0.1190 - val_accuracy: 0.0000e+00
# Epoch 718/3000
# 18/18 - 0s - loss: 0.1191 - mean_squared_error: 0.1191 - accuracy: 0.0000e+00 - val_loss: 0.1190 - val_mean_squared_error: 0.1190 - val_accuracy: 0.0000e+00
# Epoch 719/3000
# 18/18 - 0s - loss: 0.1191 - mean_squared_error: 0.1191 - accuracy: 0.0000e+00 - val_loss: 0.1190 - val_mean_squared_error: 0.1190 - val_accuracy: 0.0000e+00
# Epoch 720/3000
# 18/18 - 0s - loss: 0.1191 - mean_squared_error: 0.1191 - accuracy: 0.0000e+00 - val_loss: 0.1189 - val_mean_squared_error: 0.1189 - val_accuracy: 0.0000e+00
# Epoch 721/3000
# 18/18 - 0s - loss: 0.1191 - mean_squared_error: 0.1191 - accuracy: 0.0000e+00 - val_loss: 0.1189 - val_mean_squared_error: 0.1189 - val_accuracy: 0.0000e+00
# Epoch 722/3000
# 18/18 - 0s - loss: 0.1190 - mean_squared_error: 0.1190 - accuracy: 0.0000e+00 - val_loss: 0.1188 - val_mean_squared_error: 0.1188 - val_accuracy: 0.0000e+00
# Epoch 723/3000
# 18/18 - 0s - loss: 0.1190 - mean_squared_error: 0.1190 - accuracy: 0.0000e+00 - val_loss: 0.1188 - val_mean_squared_error: 0.1188 - val_accuracy: 0.0000e+00
# Epoch 724/3000
# 18/18 - 0s - loss: 0.1190 - mean_squared_error: 0.1190 - accuracy: 0.0000e+00 - val_loss: 0.1188 - val_mean_squared_error: 0.1188 - val_accuracy: 0.0000e+00
# Epoch 725/3000
# 18/18 - 0s - loss: 0.1189 - mean_squared_error: 0.1189 - accuracy: 0.0000e+00 - val_loss: 0.1187 - val_mean_squared_error: 0.1187 - val_accuracy: 0.0000e+00
# Epoch 726/3000
# 18/18 - 0s - loss: 0.1189 - mean_squared_error: 0.1189 - accuracy: 0.0000e+00 - val_loss: 0.1187 - val_mean_squared_error: 0.1187 - val_accuracy: 0.0000e+00
# Epoch 727/3000
# 18/18 - 0s - loss: 0.1189 - mean_squared_error: 0.1189 - accuracy: 0.0000e+00 - val_loss: 0.1186 - val_mean_squared_error: 0.1186 - val_accuracy: 0.0000e+00
# Epoch 728/3000
# 18/18 - 0s - loss: 0.1189 - mean_squared_error: 0.1189 - accuracy: 0.0000e+00 - val_loss: 0.1186 - val_mean_squared_error: 0.1186 - val_accuracy: 0.0000e+00
# Epoch 729/3000
# 18/18 - 0s - loss: 0.1188 - mean_squared_error: 0.1188 - accuracy: 0.0000e+00 - val_loss: 0.1186 - val_mean_squared_error: 0.1186 - val_accuracy: 0.0000e+00
# Epoch 730/3000
# 18/18 - 0s - loss: 0.1188 - mean_squared_error: 0.1188 - accuracy: 0.0000e+00 - val_loss: 0.1186 - val_mean_squared_error: 0.1186 - val_accuracy: 0.0000e+00
# Epoch 731/3000
# 18/18 - 0s - loss: 0.1188 - mean_squared_error: 0.1188 - accuracy: 0.0000e+00 - val_loss: 0.1185 - val_mean_squared_error: 0.1185 - val_accuracy: 0.0000e+00
# Epoch 732/3000
# 18/18 - 0s - loss: 0.1187 - mean_squared_error: 0.1187 - accuracy: 0.0000e+00 - val_loss: 0.1185 - val_mean_squared_error: 0.1185 - val_accuracy: 0.0000e+00
# Epoch 733/3000
# 18/18 - 0s - loss: 0.1187 - mean_squared_error: 0.1187 - accuracy: 0.0000e+00 - val_loss: 0.1184 - val_mean_squared_error: 0.1184 - val_accuracy: 0.0000e+00
# Epoch 734/3000
# 18/18 - 0s - loss: 0.1187 - mean_squared_error: 0.1187 - accuracy: 0.0000e+00 - val_loss: 0.1184 - val_mean_squared_error: 0.1184 - val_accuracy: 0.0000e+00
# Epoch 735/3000
# 18/18 - 0s - loss: 0.1186 - mean_squared_error: 0.1186 - accuracy: 0.0000e+00 - val_loss: 0.1184 - val_mean_squared_error: 0.1184 - val_accuracy: 0.0000e+00
# Epoch 736/3000
# 18/18 - 0s - loss: 0.1186 - mean_squared_error: 0.1186 - accuracy: 0.0000e+00 - val_loss: 0.1183 - val_mean_squared_error: 0.1183 - val_accuracy: 0.0000e+00
# Epoch 737/3000
# 18/18 - 0s - loss: 0.1186 - mean_squared_error: 0.1186 - accuracy: 0.0000e+00 - val_loss: 0.1183 - val_mean_squared_error: 0.1183 - val_accuracy: 0.0000e+00
# Epoch 738/3000
# 18/18 - 0s - loss: 0.1186 - mean_squared_error: 0.1186 - accuracy: 0.0000e+00 - val_loss: 0.1183 - val_mean_squared_error: 0.1183 - val_accuracy: 0.0000e+00
# Epoch 739/3000
# 18/18 - 0s - loss: 0.1185 - mean_squared_error: 0.1185 - accuracy: 0.0000e+00 - val_loss: 0.1182 - val_mean_squared_error: 0.1182 - val_accuracy: 0.0000e+00
# Epoch 740/3000
# 18/18 - 0s - loss: 0.1185 - mean_squared_error: 0.1185 - accuracy: 0.0000e+00 - val_loss: 0.1182 - val_mean_squared_error: 0.1182 - val_accuracy: 0.0000e+00
# Epoch 741/3000
# 18/18 - 0s - loss: 0.1185 - mean_squared_error: 0.1185 - accuracy: 0.0000e+00 - val_loss: 0.1182 - val_mean_squared_error: 0.1182 - val_accuracy: 0.0000e+00
# Epoch 742/3000
# 18/18 - 0s - loss: 0.1184 - mean_squared_error: 0.1184 - accuracy: 0.0000e+00 - val_loss: 0.1181 - val_mean_squared_error: 0.1181 - val_accuracy: 0.0000e+00
# Epoch 743/3000
# 18/18 - 0s - loss: 0.1184 - mean_squared_error: 0.1184 - accuracy: 0.0000e+00 - val_loss: 0.1181 - val_mean_squared_error: 0.1181 - val_accuracy: 0.0000e+00
# Epoch 744/3000
# 18/18 - 0s - loss: 0.1184 - mean_squared_error: 0.1184 - accuracy: 0.0000e+00 - val_loss: 0.1181 - val_mean_squared_error: 0.1181 - val_accuracy: 0.0000e+00
# Epoch 745/3000
# 18/18 - 0s - loss: 0.1183 - mean_squared_error: 0.1183 - accuracy: 0.0000e+00 - val_loss: 0.1180 - val_mean_squared_error: 0.1180 - val_accuracy: 0.0000e+00
# Epoch 746/3000
# 18/18 - 0s - loss: 0.1183 - mean_squared_error: 0.1183 - accuracy: 0.0000e+00 - val_loss: 0.1180 - val_mean_squared_error: 0.1180 - val_accuracy: 0.0000e+00
# Epoch 747/3000
# 18/18 - 0s - loss: 0.1183 - mean_squared_error: 0.1183 - accuracy: 0.0000e+00 - val_loss: 0.1179 - val_mean_squared_error: 0.1179 - val_accuracy: 0.0000e+00
# Epoch 748/3000
# 18/18 - 0s - loss: 0.1182 - mean_squared_error: 0.1182 - accuracy: 0.0000e+00 - val_loss: 0.1179 - val_mean_squared_error: 0.1179 - val_accuracy: 0.0000e+00
# Epoch 749/3000
# 18/18 - 0s - loss: 0.1182 - mean_squared_error: 0.1182 - accuracy: 0.0000e+00 - val_loss: 0.1179 - val_mean_squared_error: 0.1179 - val_accuracy: 0.0000e+00
# Epoch 750/3000
# 18/18 - 0s - loss: 0.1182 - mean_squared_error: 0.1182 - accuracy: 0.0000e+00 - val_loss: 0.1178 - val_mean_squared_error: 0.1178 - val_accuracy: 0.0000e+00
# Epoch 751/3000
# 18/18 - 0s - loss: 0.1182 - mean_squared_error: 0.1182 - accuracy: 0.0000e+00 - val_loss: 0.1178 - val_mean_squared_error: 0.1178 - val_accuracy: 0.0000e+00
# Epoch 752/3000
# 18/18 - 0s - loss: 0.1181 - mean_squared_error: 0.1181 - accuracy: 0.0000e+00 - val_loss: 0.1177 - val_mean_squared_error: 0.1177 - val_accuracy: 0.0000e+00
# Epoch 753/3000
# 18/18 - 0s - loss: 0.1181 - mean_squared_error: 0.1181 - accuracy: 0.0000e+00 - val_loss: 0.1177 - val_mean_squared_error: 0.1177 - val_accuracy: 0.0000e+00
# Epoch 754/3000
# 18/18 - 0s - loss: 0.1181 - mean_squared_error: 0.1181 - accuracy: 0.0000e+00 - val_loss: 0.1177 - val_mean_squared_error: 0.1177 - val_accuracy: 0.0000e+00
# Epoch 755/3000
# 18/18 - 0s - loss: 0.1180 - mean_squared_error: 0.1180 - accuracy: 0.0000e+00 - val_loss: 0.1177 - val_mean_squared_error: 0.1177 - val_accuracy: 0.0000e+00
# Epoch 756/3000
# 18/18 - 0s - loss: 0.1180 - mean_squared_error: 0.1180 - accuracy: 0.0000e+00 - val_loss: 0.1176 - val_mean_squared_error: 0.1176 - val_accuracy: 0.0000e+00
# Epoch 757/3000
# 18/18 - 0s - loss: 0.1180 - mean_squared_error: 0.1180 - accuracy: 0.0000e+00 - val_loss: 0.1176 - val_mean_squared_error: 0.1176 - val_accuracy: 0.0000e+00
# Epoch 758/3000
# 18/18 - 0s - loss: 0.1179 - mean_squared_error: 0.1179 - accuracy: 0.0000e+00 - val_loss: 0.1176 - val_mean_squared_error: 0.1176 - val_accuracy: 0.0000e+00
# Epoch 759/3000
# 18/18 - 0s - loss: 0.1179 - mean_squared_error: 0.1179 - accuracy: 0.0000e+00 - val_loss: 0.1175 - val_mean_squared_error: 0.1175 - val_accuracy: 0.0000e+00
# Epoch 760/3000
# 18/18 - 0s - loss: 0.1179 - mean_squared_error: 0.1179 - accuracy: 0.0000e+00 - val_loss: 0.1175 - val_mean_squared_error: 0.1175 - val_accuracy: 0.0000e+00
# Epoch 761/3000
# 18/18 - 0s - loss: 0.1178 - mean_squared_error: 0.1178 - accuracy: 0.0000e+00 - val_loss: 0.1174 - val_mean_squared_error: 0.1174 - val_accuracy: 0.0000e+00
# Epoch 762/3000
# 18/18 - 0s - loss: 0.1178 - mean_squared_error: 0.1178 - accuracy: 0.0000e+00 - val_loss: 0.1174 - val_mean_squared_error: 0.1174 - val_accuracy: 0.0000e+00
# Epoch 763/3000
# 18/18 - 0s - loss: 0.1178 - mean_squared_error: 0.1178 - accuracy: 0.0000e+00 - val_loss: 0.1174 - val_mean_squared_error: 0.1174 - val_accuracy: 0.0000e+00
# Epoch 764/3000
# 18/18 - 0s - loss: 0.1177 - mean_squared_error: 0.1177 - accuracy: 0.0000e+00 - val_loss: 0.1173 - val_mean_squared_error: 0.1173 - val_accuracy: 0.0000e+00
# Epoch 765/3000
# 18/18 - 0s - loss: 0.1177 - mean_squared_error: 0.1177 - accuracy: 0.0000e+00 - val_loss: 0.1173 - val_mean_squared_error: 0.1173 - val_accuracy: 0.0000e+00
# Epoch 766/3000
# 18/18 - 0s - loss: 0.1177 - mean_squared_error: 0.1177 - accuracy: 0.0000e+00 - val_loss: 0.1172 - val_mean_squared_error: 0.1172 - val_accuracy: 0.0000e+00
# Epoch 767/3000
# 18/18 - 0s - loss: 0.1177 - mean_squared_error: 0.1177 - accuracy: 0.0000e+00 - val_loss: 0.1172 - val_mean_squared_error: 0.1172 - val_accuracy: 0.0000e+00
# Epoch 768/3000
# 18/18 - 0s - loss: 0.1176 - mean_squared_error: 0.1176 - accuracy: 0.0000e+00 - val_loss: 0.1172 - val_mean_squared_error: 0.1172 - val_accuracy: 0.0000e+00
# Epoch 769/3000
# 18/18 - 0s - loss: 0.1176 - mean_squared_error: 0.1176 - accuracy: 0.0000e+00 - val_loss: 0.1171 - val_mean_squared_error: 0.1171 - val_accuracy: 0.0000e+00
# Epoch 770/3000
# 18/18 - 0s - loss: 0.1176 - mean_squared_error: 0.1176 - accuracy: 0.0000e+00 - val_loss: 0.1171 - val_mean_squared_error: 0.1171 - val_accuracy: 0.0000e+00
# Epoch 771/3000
# 18/18 - 0s - loss: 0.1175 - mean_squared_error: 0.1175 - accuracy: 0.0000e+00 - val_loss: 0.1170 - val_mean_squared_error: 0.1170 - val_accuracy: 0.0000e+00
# Epoch 772/3000
# 18/18 - 0s - loss: 0.1175 - mean_squared_error: 0.1175 - accuracy: 0.0000e+00 - val_loss: 0.1170 - val_mean_squared_error: 0.1170 - val_accuracy: 0.0000e+00
# Epoch 773/3000
# 18/18 - 0s - loss: 0.1175 - mean_squared_error: 0.1175 - accuracy: 0.0000e+00 - val_loss: 0.1170 - val_mean_squared_error: 0.1170 - val_accuracy: 0.0000e+00
# Epoch 774/3000
# 18/18 - 0s - loss: 0.1174 - mean_squared_error: 0.1174 - accuracy: 0.0000e+00 - val_loss: 0.1169 - val_mean_squared_error: 0.1169 - val_accuracy: 0.0000e+00
# Epoch 775/3000
# 18/18 - 0s - loss: 0.1174 - mean_squared_error: 0.1174 - accuracy: 0.0000e+00 - val_loss: 0.1169 - val_mean_squared_error: 0.1169 - val_accuracy: 0.0000e+00
# Epoch 776/3000
# 18/18 - 0s - loss: 0.1174 - mean_squared_error: 0.1174 - accuracy: 0.0000e+00 - val_loss: 0.1169 - val_mean_squared_error: 0.1169 - val_accuracy: 0.0000e+00
# Epoch 777/3000
# 18/18 - 0s - loss: 0.1173 - mean_squared_error: 0.1173 - accuracy: 0.0000e+00 - val_loss: 0.1168 - val_mean_squared_error: 0.1168 - val_accuracy: 0.0000e+00
# Epoch 778/3000
# 18/18 - 0s - loss: 0.1173 - mean_squared_error: 0.1173 - accuracy: 0.0000e+00 - val_loss: 0.1168 - val_mean_squared_error: 0.1168 - val_accuracy: 0.0000e+00
# Epoch 779/3000
# ...
# Epoch 2909/3000
# 18/18 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - accuracy: 2.7778e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 2910/3000
# 18/18 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - accuracy: 2.7778e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 2911/3000
# 18/18 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - accuracy: 2.7778e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 2912/3000
# 18/18 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - accuracy: 2.7778e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 2913/3000
# 18/18 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - accuracy: 2.7778e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 2914/3000
# 18/18 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2915/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2916/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2917/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2918/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2919/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2920/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2921/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2922/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2923/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2924/3000
# 18/18 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2925/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 2926/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2927/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2928/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2929/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2930/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2931/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2932/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2933/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2934/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2935/3000
# 18/18 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2936/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2937/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 2938/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2939/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2940/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2941/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2942/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2943/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2944/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2945/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2946/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2947/3000
# 18/18 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2948/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2949/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2950/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 2951/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2952/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2953/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2954/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2955/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2956/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2957/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2958/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2959/3000
# 18/18 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2960/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2961/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2962/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2963/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 2964/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2965/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2966/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2967/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2968/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2969/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2970/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2971/3000
# 18/18 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2972/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2973/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2974/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2975/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2976/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2977/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 2978/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2979/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2980/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2981/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2982/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2983/3000
# 18/18 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2984/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2985/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2986/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2987/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2988/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2989/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2990/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2991/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 2992/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 2993/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 2994/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 2995/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 2996/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 2997/3000
# 18/18 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 2998/3000
# 18/18 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 2999/3000
# 18/18 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 3000/3000
# 18/18 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - accuracy: 2.7778e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_accuracy: 0.0000e+00
# 0.0034994031965929697

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])

fig, err_ax = plt.subplots(1, 1)

err_ax.plot(np.arange(epochs), history.history.get('loss'))
fig.show()
# Out:
# Test loss: 0.0034994028974324465

# %%
fig, ax = plt.subplots(1, 1) 

plt.plot(x_test * RANGE, y_test * 2 - 1, 'o')
plt.plot(x_test * RANGE, model.predict(x_test) * 2 - 1, 'x')
plt.xlim([-3.3, 3.3])
plt.legend(['Samples', 'Prediction'],loc='upper right')
fig.show()

# %% [markdown]
# # Q2.B. RBF

# %%
import tensorflow as tf
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import tensorflow.compat.v1 as tf
import sys

tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class RBF:

  RANGE = 5

  def __init__(self, func):
    self.func = func

    self.n_samples = 0  # number of samples

  def add_noise_to_dataset(self, value, input, output):
      x_noise = value[0]
      y_noise = value[1]

      n = self.n_samples
      noise_x = np.random.uniform(-x_noise, x_noise, n).reshape(n, -1) 
      noise_y = np.random.uniform(-y_noise, y_noise, n).reshape(n, -1)

      input += noise_x
      output += noise_y

      return input, output

  def generate_samples(self, n_samples, noise=None):
      self.n_samples = n_samples

      x = np.linspace(-RANGE, RANGE, self.n_samples).reshape(-1,1)
      y = self.func(x)

      if noise is not None:
        x, y = self.add_noise_to_dataset(noise, x, y)

      return x, y

  def define_radial_base(self, x, c, s, hidden_size, feature):
    """
    using Gaussian bell equation to define the radial base.
    :param self: 
    :param x: 
    :param c: 
    :param s: 
    :param hidden_size: 
    :param feature: 
    :return: 
    """
    x1=tf.tile(x,[1,hidden_size]) #Copy x horizontally hidden times
    x2=tf.reshape(x1,[-1,hidden_size,feature])
    dist=tf.reduce_sum((x2-c)**2,2)
    return tf.exp(-dist/(2*s**2))

  def fit(self, x, y, hidden_size, epoch=1500):
      n_feature = x.shape[1] 

      estimator=KMeans(n_clusters=hidden_size, max_iter=10000)
      estimator.fit(x)
      cluster_center = estimator.cluster_centers_
      n = len(cluster_center)
      standard_dev = 0;
      for i in range(n):
          j=i+1
          while j < n:
              t = np.sum((cluster_center[i] - cluster_center[j]) ** 2)
              standard_dev = max(standard_dev, t)
              j = j + 1
      standard_dev =  np.sqrt(standard_dev) / np.sqrt(2*n)


      xx = tf.placeholder(tf.float32, [None, n_feature])
      yy = tf.placeholder(tf.float32, [None, 1])

      z = self.define_radial_base(xx, cluster_center, standard_dev, hidden_size, n_feature)  
  
      self.w =tf.Variable(tf.random_normal([hidden_size,1]))
      self.b = tf.Variable(tf.zeros([1]))
      yf = tf.matmul(z, self.w) + self.b
      
      loss = tf.reduce_mean(tf.square(yy-yf))
      optimizer = tf.train.AdamOptimizer(0.001)
      train = optimizer.minimize(loss)
      init = tf.global_variables_initializer()
  
      session = tf.Session()
      session.run(init)
      for iter_idx in range(epoch + 1):
          session.run(train, feed_dict={xx : x, yy : y})
          if iter_idx > 0 and iter_idx % 250 == 0:
              mse = session.run(loss,feed_dict={xx : x, yy : y})
              sys.stdout.write(f'iteration {iter_idx + 1}/{epoch + 1} \t\t [' + '=' * (iter_idx // 250) + '>' + ' ' * (epoch // 250 - iter_idx // 250) + f'] \t Error {mse}\n')
 
      pre=session.run(yf,feed_dict={xx : x, yy : y})
 
      session.close()

      print("Training has been done !")

      return pre

rbf = RBF(lambda x: np.sin(x))
x, y = rbf.generate_samples(200, (0.15, 0.15))

prediction = rbf.fit(x, y, 4, epoch=15000)
# Out:
# iteration 251/15001 		 [=>                                                           ] 	 Error 0.7706418037414551
# iteration 501/15001 		 [==>                                                          ] 	 Error 0.6980670094490051
# iteration 751/15001 		 [===>                                                         ] 	 Error 0.6587925553321838
# iteration 1001/15001 		 [====>                                                        ] 	 Error 0.6268857717514038
# iteration 1251/15001 		 [=====>                                                       ] 	 Error 0.5987396836280823
# iteration 1501/15001 		 [======>                                                      ] 	 Error 0.5723700523376465
# iteration 1751/15001 		 [=======>                                                     ] 	 Error 0.5464138984680176
# iteration 2001/15001 		 [========>                                                    ] 	 Error 0.5203287601470947
# iteration 2251/15001 		 [=========>                                                   ] 	 Error 0.49410101771354675
# iteration 2501/15001 		 [==========>                                                  ] 	 Error 0.46791908144950867
# iteration 2751/15001 		 [===========>                                                 ] 	 Error 0.44199952483177185
# iteration 3001/15001 		 [============>                                                ] 	 Error 0.416528582572937
# iteration 3251/15001 		 [=============>                                               ] 	 Error 0.3916517496109009
# iteration 3501/15001 		 [==============>                                              ] 	 Error 0.3674776554107666
# iteration 3751/15001 		 [===============>                                             ] 	 Error 0.3440841734409332
# iteration 4001/15001 		 [================>                                            ] 	 Error 0.32152506709098816
# iteration 4251/15001 		 [=================>                                           ] 	 Error 0.29983577132225037
# iteration 4501/15001 		 [==================>                                          ] 	 Error 0.27903780341148376
# iteration 4751/15001 		 [===================>                                         ] 	 Error 0.2591424882411957
# iteration 5001/15001 		 [====================>                                        ] 	 Error 0.24015338718891144
# iteration 5251/15001 		 [=====================>                                       ] 	 Error 0.22206905484199524
# iteration 5501/15001 		 [======================>                                      ] 	 Error 0.204884335398674
# iteration 5751/15001 		 [=======================>                                     ] 	 Error 0.18859180808067322
# iteration 6001/15001 		 [========================>                                    ] 	 Error 0.17318247258663177
# iteration 6251/15001 		 [=========================>                                   ] 	 Error 0.15864624083042145
# iteration 6501/15001 		 [==========================>                                  ] 	 Error 0.1449725329875946
# iteration 6751/15001 		 [===========================>                                 ] 	 Error 0.13215042650699615
# iteration 7001/15001 		 [============================>                                ] 	 Error 0.12016835063695908
# iteration 7251/15001 		 [=============================>                               ] 	 Error 0.10901451110839844
# iteration 7501/15001 		 [==============================>                              ] 	 Error 0.09867624938488007
# iteration 7751/15001 		 [===============================>                             ] 	 Error 0.08914008736610413
# iteration 8001/15001 		 [================================>                            ] 	 Error 0.0803912803530693
# iteration 8251/15001 		 [=================================>                           ] 	 Error 0.07241346687078476
# iteration 8501/15001 		 [==================================>                          ] 	 Error 0.06518834829330444
# iteration 8751/15001 		 [===================================>                         ] 	 Error 0.05869506672024727
# iteration 9001/15001 		 [====================================>                        ] 	 Error 0.05291023105382919
# iteration 9251/15001 		 [=====================================>                       ] 	 Error 0.04780738428235054
# iteration 9501/15001 		 [======================================>                      ] 	 Error 0.043356604874134064
# iteration 9751/15001 		 [=======================================>                     ] 	 Error 0.039524395018815994
# iteration 10001/15001 		 [========================================>                    ] 	 Error 0.03627344220876694
# iteration 10251/15001 		 [=========================================>                   ] 	 Error 0.03356252983212471
# iteration 10501/15001 		 [==========================================>                  ] 	 Error 0.03134661912918091
# iteration 10751/15001 		 [===========================================>                 ] 	 Error 0.029576992616057396
# iteration 11001/15001 		 [============================================>                ] 	 Error 0.02820178121328354
# iteration 11251/15001 		 [=============================================>               ] 	 Error 0.027166828513145447
# iteration 11501/15001 		 [==============================================>              ] 	 Error 0.026416806504130363
# iteration 11751/15001 		 [===============================================>             ] 	 Error 0.025896988809108734
# iteration 12001/15001 		 [================================================>            ] 	 Error 0.025555133819580078
# iteration 12251/15001 		 [=================================================>           ] 	 Error 0.025343770161271095
# iteration 12501/15001 		 [==================================================>          ] 	 Error 0.02522222511470318
# iteration 12751/15001 		 [===================================================>         ] 	 Error 0.025157971307635307
# iteration 13001/15001 		 [====================================================>        ] 	 Error 0.025127161294221878
# iteration 13251/15001 		 [=====================================================>       ] 	 Error 0.02511395514011383
# iteration 13501/15001 		 [======================================================>      ] 	 Error 0.025108983740210533
# iteration 13751/15001 		 [=======================================================>     ] 	 Error 0.02510736882686615
# iteration 14001/15001 		 [========================================================>    ] 	 Error 0.025106921792030334
# iteration 14251/15001 		 [=========================================================>   ] 	 Error 0.025106806308031082
# iteration 14501/15001 		 [==========================================================>  ] 	 Error 0.025106802582740784
# iteration 14751/15001 		 [===========================================================> ] 	 Error 0.025106795132160187
# iteration 15001/15001 		 [============================================================>] 	 Error 0.025106796994805336
# Training has been done !

# %%
plt.plot(x, y, 'o')
plt.plot(x, prediction)
plt.xlim([-3.3, 3.3])
plt.legend(['Samples with noise', 'Prediction'],loc='upper right')

# %% [markdown]
# # Q2.C. Compare

# %%
from matplotlib.pyplot import figure 

figure(figsize=(8, 6), dpi=160)

x_exact, y_exact = rbf.generate_samples(200, None)
plt.plot(x_exact, y_exact)
x, y = rbf.add_noise_to_dataset((0.15, 0.15), x_exact, y_exact)
plt.plot(x, y, '*')
plt.plot(x * RANGE, model.predict(x) * 2 - 1, '+')  # MLP
plt.plot(x, prediction, 'x')  # RBF
plt.xlim([-4, 4])
plt.legend(['Real', 'Samples', 'MPL Prediction', 'RBF Prediction'],loc='upper right')

# %% [markdown]
# # <font color='red'>Submission</font>
#
# 1. Sign up in [Gradescope](https://www.gradescope.com) with proper name and student ID and use the following code to join the class: <font color='red'>**D5372R**</font>
# 2. Fill in your full name (seperated by single spaces) and student ID in the beginning of this notebook.
# 3. After you're done with this notebook, you should do the following:
#   - Clear all outputs of the notebook.
#   ![clear all outputs](https://i.ibb.co/y6FrttB/Screen-Shot-2021-03-21-at-01-51-42.png)
#   - Run all of the cells (if you skipped a question just leave the cell unchanged), and make sure all of your outputs are correct.
#   ![run all](https://i.ibb.co/cgRcBZ0/Screen-Shot-2021-03-21-at-01-54-58.png)
#   - Save your notebook.
#
#   - If you're using Colab, download your notebook.
#   ![download ipynb](https://i.ibb.co/2KxYM6K/Screen-Shot-2021-03-21-at-02-03-50.png)
#
#   - Put the notebook file you just downloaded and `convert.py` in the same folder run the following command:
#   ```bash
#   python convert.py
#   ```
#   This will export your code for each question into a `.py` file.
#
#
#   according to the question number.
#   - There are 2 assignments in Gradescope:
#
#     You should upload your **codes** and your **notebook** in `HW2` section and your final report for all of the questions as a **single pdf** file in `HW2 - Report`. Autograder will automatically check for:
#     - `CI992_HW2.ipynb`
#     - `Q1.A. Kohonen.py`
#     - `Q1.B. Koohonen.py`
#     - `Q2.A. MLP.py`
#     - `Q2.B. RBF.py`
#     - `Q2.C. Compare.py`
#     - Your name and ID in the beginning of `.ipynb` file.
#
#     It is important that you <font color='red'>**don't**</font> change the names of these files before submission.
#
# 4. If you pass the autograder, you're good to go.
